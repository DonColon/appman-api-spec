# %% [markdown]
# # Extraktion der Zeitzonen und deren Offset
#
# Dieses Notebook extrahiert aus der Wikipage für die [tz database](https://en.wikipedia.org/wiki/List_of_tz_database_time_zones) die Zeitzonen speichert sie in einem CSV.

# %%
from bs4 import BeautifulSoup
import requests
import pandas

# %%
response = requests.get("https://en.wikipedia.org/wiki/List_of_tz_database_time_zones")

htmlContent = response.text

htmlContent
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of tz database time zones - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"YEL6mQ9wCW8N9z2pxp-afQAAAAA","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"List_of_tz_database_time_zones","wgTitle":"List of tz database time zones","wgCurRevisionId":1004588891,"wgRevisionId":1004588891,"wgArticleId":6051179,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Tz database","Time zones"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"List_of_tz_database_time_zones","wgRelevantArticleId":6051179,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],\n"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsReferencePreviewsBeta":!0,"wgPopupsConflictsWithNavPopupGadget":!1,"wgPopupsConflictsWithRefTooltipsGadget":!0,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0,"wgULSPosition":"interlanguage","wgWikibaseItemId":"Q6644192"};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.styles.legacy":"ready","jquery.tablesorter.styles":"ready","jquery.makeCollapsible.styles":\n"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","jquery.tablesorter","jquery.makeCollapsible","mediawiki.toc","skins.vector.legacy.js","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.refToolbar","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.centralNotice.geoIP","ext.centralNotice.startUp"];</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1hzgi",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});\n});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cjquery.tablesorter.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>\n<script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector"></script>\n<meta name="ResourceLoaderDynamicStyles" content=""/>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>\n<meta name="generator" content="MediaWiki 1.36.0-wmf.33"/>\n<meta name="referrer" content="origin"/>\n<meta name="referrer" content="origin-when-crossorigin"/>\n<meta name="referrer" content="origin-when-cross-origin"/>\n<meta property= ...

# %%
soup = BeautifulSoup(htmlContent, "html5lib")
table = soup.table

table
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th><a class="mw-redirect" href="/wiki/ISO_3166_2-character_country_code" title="ISO 3166 2-character country code">Country code</a>
# </th>
# <th><a href="/wiki/ISO_6709" title="ISO 6709">Latitude, longitude ±DDMM(SS)±DDDMM(SS)</a>
# </th>
# <th>TZ database name
# </th>
# <th>Portion of country covered
# </th>
# <th>Status
# </th>
# <th>UTC offset ±hh:mm
# </th>
# <th>UTC DST offset ±hh:mm
# </th>
# <th>Notes
# </th></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:CI" title="ISO 3166-1:CI">CI</a>
# </td>
# <td>+0519−00402
# </td>
# <td><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">Africa/Abidjan</a>
# </td>
# <td>
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:GH" title="ISO 3166-1:GH">GH</a>
# </td>
# <td>+0533−00013
# </td>
# <td><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">Africa/Accra</a>
# </td>
# <td>
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:ET" title="ISO 3166-1:ET">ET</a>
# </td>
# <td>+0902+03842
# </td>
# <td><a href="/wiki/East_Africa_Time" title="East Africa Time">Africa/Addis_Ababa</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
# </td>
# <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
# </td>
# <td>Link to <a href="/wiki/East_Africa_Time" title="East Africa Time">Africa/Nairobi</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:DZ" title="ISO 3166-1:DZ">DZ</a>
# </td>
# <td>+3647+00303
# </td>
# <td><a href="/wiki/Central_European_Time" title="Central European Time">Africa/Algiers</a>
# </td>
# <td>
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:ER" title="ISO 3166-1:ER">ER</a>
# </td>
# <td>+1520+03853
# </td>
# <td><a href="/wiki/East_Africa_Time" title="East Africa Time">Africa/Asmara</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
# </td>
# <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
# </td>
# <td>Link to <a href="/wiki/East_Africa_Time" title="East Africa Time">Africa/Nairobi</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:ER" title="ISO 3166-1:ER">ER</a>
# </td>
# <td>+1520+03853
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Asmera&amp;action=edit&amp;redlink=1" title="Africa/Asmera (page does not exist)">Africa/Asmera</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
# </td>
# <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
# </td>
# <td>Link to <a href="/wiki/East_Africa_Time" title="East Africa Time">Africa/Nairobi</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:ML" title="ISO 3166-1:ML">ML</a>
# </td>
# <td>+1239−00800
# </td>
# <td><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">Africa/Bamako</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Abidjan</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:CF" title="ISO 3166-1:CF">CF</a>
# </td>
# <td>+0422+01835
# </td>
# <td><a href="/wiki/West_Africa_Time" title="West Africa Time">Africa/Bangui</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Lagos</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:GM" title="ISO 3166-1:GM">GM</a>
# </td>
# <td>+1328−01639
# </td>
# <td><a href="/wiki/Greenwich_Mean_Time" title="Greenwich Mean Time">Africa/Banjul</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Abidjan</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:GW" title="ISO 3166-1:GW">GW</a>
# </td>
# <td>+1151−01535
# </td>
# <td><a class="mw-redirect" href="/wiki/GMT" title="GMT">Africa/Bissau</a>
# </td>
# <td>
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:MW" title="ISO 3166-1:MW">MW</a>
# </td>
# <td>−1547+03500
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Blantyre</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Maputo</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:CG" title="ISO 3166-1:CG">CG</a>
# </td>
# <td>−0416+01517
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Brazzaville</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Lagos</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:BI" title="ISO 3166-1:BI">BI</a>
# </td>
# <td>−0323+02922
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Bujumbura</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Maputo</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:EG" title="ISO 3166-1:EG">EG</a>
# </td>
# <td>+3003+03115
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Cairo&amp;action=edit&amp;redlink=1" title="Africa/Cairo (page does not exist)">Africa/Cairo</a>
# </td>
# <td>
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:MA" title="ISO 3166-1:MA">MA</a>
# </td>
# <td>+3339−00735
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Casablanca&amp;action=edit&amp;redlink=1" title="Africa/Casablanca (page does not exist)">Africa/Casablanca</a>
# </td>
# <td>
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:ES" title="ISO 3166-1:ES">ES</a>
# </td>
# <td>+3553−00519
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Ceuta&amp;action=edit&amp;redlink=1" title="Africa/Ceuta (page does not exist)">Africa/Ceuta</a>
# </td>
# <td>Ceuta, Melilla
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:GN" title="ISO 3166-1:GN">GN</a>
# </td>
# <td>+0931−01343
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Conakry</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Abidjan</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:SN" title="ISO 3166-1:SN">SN</a>
# </td>
# <td>+1440−01726
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Dakar</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Abidjan</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:TZ" title="ISO 3166-1:TZ">TZ</a>
# </td>
# <td>−0648+03917
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Nairobi&amp;action=edit&amp;redlink=1" title="Africa/Nairobi (page does not exist)">Africa/Dar_es_Salaam</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
# </td>
# <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
# </td>
# <td>Link to <a href="/wiki/East_Africa_Time" title="East Africa Time">Africa/Nairobi</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:DJ" title="ISO 3166-1:DJ">DJ</a>
# </td>
# <td>+1136+04309
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Nairobi&amp;action=edit&amp;redlink=1" title="Africa/Nairobi (page does not exist)">Africa/Djibouti</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
# </td>
# <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
# </td>
# <td>Link to <a href="/wiki/East_Africa_Time" title="East Africa Time">Africa/Nairobi</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:CM" title="ISO 3166-1:CM">CM</a>
# </td>
# <td>+0403+00942
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Douala</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Lagos</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:EH" title="ISO 3166-1:EH">EH</a>
# </td>
# <td>+2709−01312
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/El_Aaiun&amp;action=edit&amp;redlink=1" title="Africa/El Aaiun (page does not exist)">Africa/El_Aaiun</a>
# </td>
# <td>
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:SL" title="ISO 3166-1:SL">SL</a>
# </td>
# <td>+0830−01315
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Freetown</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Abidjan</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:BW" title="ISO 3166-1:BW">BW</a>
# </td>
# <td>−2439+02555
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Gaborone</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Maputo</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:ZW" title="ISO 3166-1:ZW">ZW</a>
# </td>
# <td>−1750+03103
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Harare</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Maputo</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:ZA" title="ISO 3166-1:ZA">ZA</a>
# </td>
# <td>−2615+02800
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Johannesburg&amp;action=edit&amp;redlink=1" title="Africa/Johannesburg (page does not exist)">Africa/Johannesburg</a>
# </td>
# <td>
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:SS" title="ISO 3166-1:SS">SS</a>
# </td>
# <td>+0451+03137
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Juba&amp;action=edit&amp;redlink=1" title="Africa/Juba (page does not exist)">Africa/Juba</a>
# </td>
# <td>
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:UG" title="ISO 3166-1:UG">UG</a>
# </td>
# <td>+0019+03225
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Nairobi&amp;action=edit&amp;redlink=1" title="Africa/Nairobi (page does not exist)">Africa/Kampala</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
# </td>
# <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
# </td>
# <td>Link to <a href="/wiki/East_Africa_Time" title="East Africa Time">Africa/Nairobi</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:SD" title="ISO 3166-1:SD">SD</a>
# </td>
# <td>+1536+03232
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Khartoum&amp;action=edit&amp;redlink=1" title="Africa/Khartoum (page does not exist)">Africa/Khartoum</a>
# </td>
# <td>
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:RW" title="ISO 3166-1:RW">RW</a>
# </td>
# <td>−0157+03004
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Kigali</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Maputo</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:CD" title="ISO 3166-1:CD">CD</a>
# </td>
# <td>−0418+01518
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Kinshasa</a>
# </td>
# <td>Dem. Rep. of Congo (west)
# </td>
# <td>Alias
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Lagos</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:NG" title="ISO 3166-1:NG">NG</a>
# </td>
# <td>+0627+00324
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Lagos</a>
# </td>
# <td>West Africa Time
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:GA" title="ISO 3166-1:GA">GA</a>
# </td>
# <td>+0023+00927
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Libreville</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Lagos</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:TG" title="ISO 3166-1:TG">TG</a>
# </td>
# <td>+0608+00113
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Lome</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Abidjan</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AO" title="ISO 3166-1:AO">AO</a>
# </td>
# <td>−0848+01314
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Luanda</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Lagos</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:CD" title="ISO 3166-1:CD">CD</a>
# </td>
# <td>−1140+02728
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Lubumbashi</a>
# </td>
# <td>Dem. Rep. of Congo (east)
# </td>
# <td>Alias
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Maputo</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:ZM" title="ISO 3166-1:ZM">ZM</a>
# </td>
# <td>−1525+02817
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Lusaka</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Maputo</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:GQ" title="ISO 3166-1:GQ">GQ</a>
# </td>
# <td>+0345+00847
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Malabo</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Lagos</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:MZ" title="ISO 3166-1:MZ">MZ</a>
# </td>
# <td>−2558+03235
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Maputo</a>
# </td>
# <td>Central Africa Time
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:LS" title="ISO 3166-1:LS">LS</a>
# </td>
# <td>−2928+02730
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Johannesburg&amp;action=edit&amp;redlink=1" title="Africa/Johannesburg (page does not exist)">Africa/Maseru</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Africa/Johannesburg&amp;action=edit&amp;redlink=1" title="Africa/Johannesburg (page does not exist)">Africa/Johannesburg</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:SZ" title="ISO 3166-1:SZ">SZ</a>
# </td>
# <td>−2618+03106
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Johannesburg&amp;action=edit&amp;redlink=1" title="Africa/Johannesburg (page does not exist)">Africa/Mbabane</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Africa/Johannesburg&amp;action=edit&amp;redlink=1" title="Africa/Johannesburg (page does not exist)">Africa/Johannesburg</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:SO" title="ISO 3166-1:SO">SO</a>
# </td>
# <td>+0204+04522
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Nairobi&amp;action=edit&amp;redlink=1" title="Africa/Nairobi (page does not exist)">Africa/Mogadishu</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
# </td>
# <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
# </td>
# <td>Link to <a href="/wiki/East_Africa_Time" title="East Africa Time">Africa/Nairobi</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:LR" title="ISO 3166-1:LR">LR</a>
# </td>
# <td>+0618−01047
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Monrovia&amp;action=edit&amp;redlink=1" title="Africa/Monrovia (page does not exist)">Africa/Monrovia</a>
# </td>
# <td>
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:KE" title="ISO 3166-1:KE">KE</a>
# </td>
# <td>−0117+03649
# </td>
# <td><a href="/wiki/East_Africa_Time" title="East Africa Time">Africa/Nairobi</a>
# </td>
# <td>
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
# </td>
# <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:TD" title="ISO 3166-1:TD">TD</a>
# </td>
# <td>+1207+01503
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Ndjamena&amp;action=edit&amp;redlink=1" title="Africa/Ndjamena (page does not exist)">Africa/Ndjamena</a>
# </td>
# <td>
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:NE" title="ISO 3166-1:NE">NE</a>
# </td>
# <td>+1331+00207
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Niamey</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Lagos</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:MR" title="ISO 3166-1:MR">MR</a>
# </td>
# <td>+1806−01557
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Nouakchott</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Abidjan</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:BF" title="ISO 3166-1:BF">BF</a>
# </td>
# <td>+1222−00131
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Ouagadougou</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Abidjan</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:BJ" title="ISO 3166-1:BJ">BJ</a>
# </td>
# <td>+0629+00237
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Porto-Novo</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Lagos</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:ST" title="ISO 3166-1:ST">ST</a>
# </td>
# <td>+0020+00644
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Sao_Tome</a>
# </td>
# <td>
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:ML" title="ISO 3166-1:ML">ML</a>
# </td>
# <td>
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Timbuktu</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Abidjan</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:LY" title="ISO 3166-1:LY">LY</a>
# </td>
# <td>+3254+01311
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Tripoli&amp;action=edit&amp;redlink=1" title="Africa/Tripoli (page does not exist)">Africa/Tripoli</a>
# </td>
# <td>
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:TN" title="ISO 3166-1:TN">TN</a>
# </td>
# <td>+3648+01011
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Tunis&amp;action=edit&amp;redlink=1" title="Africa/Tunis (page does not exist)">Africa/Tunis</a>
# </td>
# <td>
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:NA" title="ISO 3166-1:NA">NA</a>
# </td>
# <td>−2234+01706
# </td>
# <td><a class="new" href="/w/index.php?title=Africa/Windhoek&amp;action=edit&amp;redlink=1" title="Africa/Windhoek (page does not exist)">Africa/Windhoek</a>
# </td>
# <td>
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:US" title="ISO 3166-1:US">US</a>
# </td>
# <td>+515248−1763929
# </td>
# <td><a class="mw-redirect" href="/wiki/America/Adak" title="America/Adak">America/Adak</a>
# </td>
# <td>Aleutian Islands
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="-10"><a href="/wiki/UTC%E2%88%9210:00" title="UTC−10:00">−10:00</a>
# </td>
# <td data-sort-value="-9"><a href="/wiki/UTC%E2%88%9209:00" title="UTC−09:00">−09:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:US" title="ISO 3166-1:US">US</a>
# </td>
# <td>+611305−1495401
# </td>
# <td><a class="mw-redirect" href="/wiki/America/Anchorage" title="America/Anchorage">America/Anchorage</a>
# </td>
# <td>Alaska (most areas)
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="-9"><a href="/wiki/UTC%E2%88%9209:00" title="UTC−09:00">−09:00</a>
# </td>
# <td data-sort-value="-8"><a href="/wiki/UTC%E2%88%9208:00" title="UTC−08:00">−08:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AI" title="ISO 3166-1:AI">AI</a>
# </td>
# <td>+1812−06304
# </td>
# <td><a class="mw-redirect" href="/wiki/America/Port_of_Spain" title="America/Port of Spain">America/Anguilla</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
# </td>
# <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
# </td>
# <td>Link to <a class="mw-redirect" href="/wiki/America/Port_of_Spain" title="America/Port of Spain">America/Port_of_Spain</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AG" title="ISO 3166-1:AG">AG</a>
# </td>
# <td>+1703−06148
# </td>
# <td><a class="mw-redirect" href="/wiki/America/Port_of_Spain" title="America/Port of Spain">America/Antigua</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
# </td>
# <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
# </td>
# <td>Link to <a class="mw-redirect" href="/wiki/America/Port_of_Spain" title="America/Port of Spain">America/Port_of_Spain</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:BR" title="ISO 3166-1:BR">BR</a>
# </td>
# <td>−0712−04812
# </td>
# <td><a class="new" href="/w/index.php?title=America/Araguaina&amp;action=edit&amp;redlink=1" title="America/Araguaina (page does not exist)">America/Araguaina</a>
# </td>
# <td>Tocantins
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AR" title="ISO 3166-1:AR">AR</a>
# </td>
# <td>−3436−05827
# </td>
# <td><a class="new" href="/w/index.php?title=America/Argentina/Buenos_Aires&amp;action=edit&amp;redlink=1" title="America/Argentina/Buenos Aires (page does not exist)">America/Argentina/Buenos_Aires</a>
# </td>
# <td>Buenos Aires (BA, CF)
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AR" title="ISO 3166-1:AR">AR</a>
# </td>
# <td>−2828−06547
# </td>
# <td><a class="new" href="/w/index.php?title=America/Argentina/Catamarca&amp;action=edit&amp;redlink=1" title="America/Argentina/Catamarca (page does not exist)">America/Argentina/Catamarca</a>
# </td>
# <td>Catamarca (CT); Chubut (CH)
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AR" title="ISO 3166-1:AR">AR</a>
# </td>
# <td>
# </td>
# <td><a class="new" href="/w/index.php?title=America/Argentina/Catamarca&amp;action=edit&amp;redlink=1" title="America/Argentina/Catamarca (page does not exist)">America/Argentina/ComodRivadavia</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=America/Argentina/Catamarca&amp;action=edit&amp;redlink=1" title="America/Argentina/Catamarca (page does not exist)">America/Argentina/Catamarca</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AR" title="ISO 3166-1:AR">AR</a>
# </td>
# <td>−3124−06411
# </td>
# <td><a class="new" href="/w/index.php?title=America/Argentina/Cordoba&amp;action=edit&amp;redlink=1" title="America/Argentina/Cordoba (page does not exist)">America/Argentina/Cordoba</a>
# </td>
# <td>Argentina (most areas: CB, CC, CN, ER, FM, MN, SE, SF)
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AR" title="ISO 3166-1:AR">AR</a>
# </td>
# <td>−2411−06518
# </td>
# <td><a class="new" href="/w/index.php?title=America/Argentina/Jujuy&amp;action=edit&amp;redlink=1" title="America/Argentina/Jujuy (page does not exist)">America/Argentina/Jujuy</a>
# </td>
# <td>Jujuy (JY)
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AR" title="ISO 3166-1:AR">AR</a>
# </td>
# <td>−2926−06651
# </td>
# <td><a class="new" href="/w/index.php?title=America/Argentina/La_Rioja&amp;action=edit&amp;redlink=1" title="America/Argentina/La Rioja (page does not exist)">America/Argentina/La_Rioja</a>
# </td>
# <td>La Rioja (LR)
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AR" title="ISO 3166-1:AR">AR</a>
# </td>
# <td>−3253−06849
# </td>
# <td><a class="new" href="/w/index.php?title=America/Argentina/Mendoza&amp;action=edit&amp;redlink=1" title="America/Argentina/Mendoza (page does not exist)">America/Argentina/Mendoza</a>
# </td>
# <td>Mendoza (MZ)
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AR" title="ISO 3166-1:AR">AR</a>
# </td>
# <td>−5138−06913
# </td>
# <td><a class="new" href="/w/index.php?title=America/Argentina/Rio_Gallegos&amp;action=edit&amp;redlink=1" title="America/Argentina/Rio Gallegos (page does not exist)">America/Argentina/Rio_Gallegos</a>
# </td>
# <td>Santa Cruz (SC)
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AR" title="ISO 3166-1:AR">AR</a>
# </td>
# <td>−2447−06525
# </td>
# <td><a class="new" href="/w/index.php?title=America/Argentina/Salta&amp;action=edit&amp;redlink=1" title="America/Argentina/Salta (page does not exist)">America/Argentina/Salta</a>
# </td>
# <td>Salta (SA, LP, NQ, RN)
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AR" title="ISO 3166-1:AR">AR</a>
# </td>
# <td>−3132−06831
# </td>
# <td><a class="new" href="/w/index.php?title=America/Argentina/San_Juan&amp;action=edit&amp;redlink=1" title="America/Argentina/San Juan (page does not exist)">America/Argentina/San_Juan</a>
# </td>
# <td>San Juan (SJ)
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AR" title="ISO 3166-1:AR">AR</a>
# </td>
# <td>−3319−06621
# </td>
# <td><a class="new" href="/w/index.php?title=America/Argentina/San_Luis&amp;action=edit&amp;redlink=1" title="America/Argentina/San Luis (page does not exist)">America/Argentina/San_Luis</a>
# </td>
# <td>San Luis (SL)
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AR" title="ISO 3166-1:AR">AR</a>
# </td>
# <td>−2649−06513
# </td>
# <td><a class="new" href="/w/index.php?title=America/Argentina/Tucuman&amp;action=edit&amp;redlink=1" title="America/Argentina/Tucuman (page does not exist)">America/Argentina/Tucuman</a>
# </td>
# <td>Tucumán (TM)
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AR" title="ISO 3166-1:AR">AR</a>
# </td>
# <td>−5448−06818
# </td>
# <td><a class="new" href="/w/index.php?title=America/Argentina/Ushuaia&amp;action=edit&amp;redlink=1" title="America/Argentina/Ushuaia (page does not exist)">America/Argentina/Ushuaia</a>
# </td>
# <td>Tierra del Fuego (TF)
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AW" title="ISO 3166-1:AW">AW</a>
# </td>
# <td>+1230−06958
# </td>
# <td><a class="new" href="/w/index.php?title=America/Curacao&amp;action=edit&amp;redlink=1" title="America/Curacao (page does not exist)">America/Aruba</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
# </td>
# <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=America/Curacao&amp;action=edit&amp;redlink=1" title="America/Curacao (page does not exist)">America/Curacao</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:PY" title="ISO 3166-1:PY">PY</a>
# </td>
# <td>−2516−05740
# </td>
# <td><a class="new" href="/w/index.php?title=America/Asuncion&amp;action=edit&amp;redlink=1" title="America/Asuncion (page does not exist)">America/Asuncion</a>
# </td>
# <td>
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:CA" title="ISO 3166-1:CA">CA</a>
# </td>
# <td>+484531−0913718
# </td>
# <td><a class="new" href="/w/index.php?title=America/Atikokan&amp;action=edit&amp;redlink=1" title="America/Atikokan (page does not exist)">America/Atikokan</a>
# </td>
# <td>EST - ON (Atikokan); NU (Coral H)
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="-5"><a href="/wiki/UTC%E2%88%9205:00" title="UTC−05:00">−05:00</a>
# </td>
# <td data-sort-value="-5"><a href="/wiki/UTC%E2%88%9205:00" title="UTC−05:00">−05:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:US" title="ISO 3166-1:US">US</a>
# </td>
# <td>
# </td>
# <td><a class="mw-redirect" href="/wiki/America/Adak" title="America/Adak">America/Atka</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="-10"><a href="/wiki/UTC%E2%88%9210:00" title="UTC−10:00">−10:00</a>
# </td>
# <td data-sort-value="-9"><a href="/wiki/UTC%E2%88%9209:00" title="UTC−09:00">−09:00</a>
# </td>
# <td>Link to <a class="mw-redirect" href="/wiki/America/Adak" title="America/Adak">America/Adak</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:BR" title="ISO 3166-1:BR">BR</a>
# </td>
# <td>−1259−03831
# </td>
# <td><a class="new" href="/w/index.php?title=America/Bahia&amp;action=edit&amp;redlink=1" title="America/Bahia (page does not exist)">America/Bahia</a>
# </td>
# <td>Bahia
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:MX" title="ISO 3166-1:MX">MX</a>
# </td>
# <td>+2048−10515
# </td>
# <td><a class="new" href="/w/index.php?title=America/Bahia_Banderas&amp;action=edit&amp;redlink=1" title="America/Bahia Banderas (page does not exist)">America/Bahia_Banderas</a>
# </td>
# <td>Central Time - Bahía de Banderas
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="-6"><a href="/wiki/UTC%E2%88%9206:00" title="UTC−06:00">−06:00</a>
# </td>
# <td data-sort-value="-5"><a href="/wiki/UTC%E2%88%9205:00" title="UTC−05:00">−05:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:BB" title="ISO 3166-1:BB">BB</a>
# </td>
# <td>+1306−05937
# </td>
# <td><a class="new" href="/w/index.php?title=America/Barbados&amp;action=edit&amp;redlink=1" title="America/Barbados (page does not exist)">America/Barbados</a>
# </td>
# <td>
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
# </td>
# <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:BR" title="ISO 3166-1:BR">BR</a>
# </td>
# <td>−0127−04829
# </td>
# <td><a class="new" href="/w/index.php?title=America/Belem&amp;action=edit&amp;redlink=1" title="America/Belem (page does not exist)">America/Belem</a>
# </td>
# <td>Pará (east); Amapá
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:BZ" title="ISO 3166-1:BZ">BZ</a>
# </td>
# <td>+1730−08812
# </td>
# <td><a class="new" href="/w/index.php?title=America/Belize&amp;action=edit&amp;redlink=1" title="America/Belize (page does not exist)">America/Belize</a>
# </td>
# <td>
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="-6"><a href="/wiki/UTC%E2%88%9206:00" title="UTC−06:00">−06:00</a>
# </td>
# <td data-sort-value="-6"><a href="/wiki/UTC%E2%88%9206:00" title="UTC−06:00">−06:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:CA" title="ISO 3166-1:CA">CA</a>
# </td>
# <td>+5125−05707
# </td>
# <td><a class="new" href="/w/index.php?title=America/Blanc-Sablon&amp;action=edit&amp;redlink=1" title="America/Blanc-Sablon (page does not exist)">America/Blanc-Sablon</a>
# </td>
# <td>AST - QC (Lower North Shore)
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
# </td>
# <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:BR" title="ISO 3166-1:BR">BR</a>
# </td>
# <td>+0249−06040
# </td>
# <td><a class="new" href="/w/index.php?title=America/Boa_Vista&amp;action=edit&amp;redlink=1" title="America/Boa Vista (page does not exist)">America/Boa_Vista</a>
# </td>
# <td>Roraima
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
# </td>
# <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:CO" title="ISO 3166-1:CO">CO</a>
# </td>
# <td>+0436−07405
# </td>
# <td><a class="new" href="/w/index.php?title=America/Bogota&amp;action=edit&amp;redlink=1" title="America/Bogota (page does not exist)">America/Bogota</a>
# </td>
# <td>
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="-5"><a href="/wiki/UTC%E2%88%9205:00" title="UTC−05:00">−05:00</a>
# </td>
# ...
# <td data-sort-value="10"><a href="/wiki/UTC%2B10:00" title="UTC+10:00">+10:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Pacific/Chuuk&amp;action=edit&amp;redlink=1" title="Pacific/Chuuk (page does not exist)">Pacific/Chuuk</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:UM" title="ISO 3166-1:UM">UM</a>
# </td>
# <td>+1917+16637
# </td>
# <td><a class="new" href="/w/index.php?title=Pacific/Wake&amp;action=edit&amp;redlink=1" title="Pacific/Wake (page does not exist)">Pacific/Wake</a>
# </td>
# <td>Wake Island
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="12"><a href="/wiki/UTC%2B12:00" title="UTC+12:00">+12:00</a>
# </td>
# <td data-sort-value="12"><a href="/wiki/UTC%2B12:00" title="UTC+12:00">+12:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:WF" title="ISO 3166-1:WF">WF</a>
# </td>
# <td>−1318−17610
# </td>
# <td><a class="new" href="/w/index.php?title=Pacific/Wallis&amp;action=edit&amp;redlink=1" title="Pacific/Wallis (page does not exist)">Pacific/Wallis</a>
# </td>
# <td>
# </td>
# <td>Canonical
# </td>
# <td data-sort-value="12"><a href="/wiki/UTC%2B12:00" title="UTC+12:00">+12:00</a>
# </td>
# <td data-sort-value="12"><a href="/wiki/UTC%2B12:00" title="UTC+12:00">+12:00</a>
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:FM" title="ISO 3166-1:FM">FM</a>
# </td>
# <td>
# </td>
# <td><a class="new" href="/w/index.php?title=Pacific/Chuuk&amp;action=edit&amp;redlink=1" title="Pacific/Chuuk (page does not exist)">Pacific/Yap</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="10"><a href="/wiki/UTC%2B10:00" title="UTC+10:00">+10:00</a>
# </td>
# <td data-sort-value="10"><a href="/wiki/UTC%2B10:00" title="UTC+10:00">+10:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Pacific/Chuuk&amp;action=edit&amp;redlink=1" title="Pacific/Chuuk (page does not exist)">Pacific/Chuuk</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:PL" title="ISO 3166-1:PL">PL</a>
# </td>
# <td>
# </td>
# <td><a class="new" href="/w/index.php?title=Europe/Warsaw&amp;action=edit&amp;redlink=1" title="Europe/Warsaw (page does not exist)">Poland</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Europe/Warsaw&amp;action=edit&amp;redlink=1" title="Europe/Warsaw (page does not exist)">Europe/Warsaw</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:PT" title="ISO 3166-1:PT">PT</a>
# </td>
# <td>
# </td>
# <td><a class="mw-redirect" href="/wiki/Europe/Lisbon" title="Europe/Lisbon">Portugal</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td>Link to <a class="mw-redirect" href="/wiki/Europe/Lisbon" title="Europe/Lisbon">Europe/Lisbon</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:CN" title="ISO 3166-1:CN">CN</a>
# </td>
# <td>
# </td>
# <td><a class="mw-redirect" href="/wiki/Asia/Shanghai" title="Asia/Shanghai">PRC</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="8"><a href="/wiki/UTC%2B08:00" title="UTC+08:00">+08:00</a>
# </td>
# <td data-sort-value="8"><a href="/wiki/UTC%2B08:00" title="UTC+08:00">+08:00</a>
# </td>
# <td>Link to <a class="mw-redirect" href="/wiki/Asia/Shanghai" title="Asia/Shanghai">Asia/Shanghai</a>
# </td></tr>
# <tr>
# <td>
# </td>
# <td>
# </td>
# <td><a class="mw-redirect" href="/wiki/PST8PDT" title="PST8PDT">PST8PDT</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="-8"><a href="/wiki/UTC%E2%88%9208:00" title="UTC−08:00">−08:00</a>
# </td>
# <td data-sort-value="-7"><a href="/wiki/UTC%E2%88%9207:00" title="UTC−07:00">−07:00</a>
# </td>
# <td>Choose a zone that <i>observes</i> PST with United States daylight saving time rules, such as <a class="mw-redirect" href="/wiki/America/Los_Angeles" title="America/Los Angeles">America/Los_Angeles</a>.
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:TW" title="ISO 3166-1:TW">TW</a>
# </td>
# <td>
# </td>
# <td><a class="mw-redirect" href="/wiki/Asia/Taipei" title="Asia/Taipei">ROC</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="8"><a href="/wiki/UTC%2B08:00" title="UTC+08:00">+08:00</a>
# </td>
# <td data-sort-value="8"><a href="/wiki/UTC%2B08:00" title="UTC+08:00">+08:00</a>
# </td>
# <td>Link to <a class="mw-redirect" href="/wiki/Asia/Taipei" title="Asia/Taipei">Asia/Taipei</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:KR" title="ISO 3166-1:KR">KR</a>
# </td>
# <td>
# </td>
# <td><a href="/wiki/Time_in_South_Korea" title="Time in South Korea">ROK</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="9"><a href="/wiki/UTC%2B09:00" title="UTC+09:00">+09:00</a>
# </td>
# <td data-sort-value="9"><a href="/wiki/UTC%2B09:00" title="UTC+09:00">+09:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Asia/Seoul&amp;action=edit&amp;redlink=1" title="Asia/Seoul (page does not exist)">Asia/Seoul</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:SG" title="ISO 3166-1:SG">SG</a>
# </td>
# <td>+0117+10351
# </td>
# <td><a class="mw-redirect" href="/wiki/Asia/Singapore" title="Asia/Singapore">Singapore</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="8"><a href="/wiki/UTC%2B08:00" title="UTC+08:00">+08:00</a>
# </td>
# <td data-sort-value="8"><a href="/wiki/UTC%2B08:00" title="UTC+08:00">+08:00</a>
# </td>
# <td>Link to <a class="mw-redirect" href="/wiki/Asia/Singapore" title="Asia/Singapore">Asia/Singapore</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:TR" title="ISO 3166-1:TR">TR</a>
# </td>
# <td>
# </td>
# <td><a href="/wiki/Time_in_Turkey" title="Time in Turkey">Turkey</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
# </td>
# <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Europe/Istanbul&amp;action=edit&amp;redlink=1" title="Europe/Istanbul (page does not exist)">Europe/Istanbul</a>
# </td></tr>
# <tr>
# <td>
# </td>
# <td>
# </td>
# <td><a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">UCT</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td>Link to <a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">Etc/UTC</a>
# </td></tr>
# <tr>
# <td>
# </td>
# <td>
# </td>
# <td><a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">Universal</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td>Link to <a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">Etc/UTC</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:US" title="ISO 3166-1:US">US</a>
# </td>
# <td>
# </td>
# <td><a class="mw-redirect" href="/wiki/America/Anchorage" title="America/Anchorage">US/Alaska</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="-9"><a href="/wiki/UTC%E2%88%9209:00" title="UTC−09:00">−09:00</a>
# </td>
# <td data-sort-value="-8"><a href="/wiki/UTC%E2%88%9208:00" title="UTC−08:00">−08:00</a>
# </td>
# <td>Link to <a class="mw-redirect" href="/wiki/America/Anchorage" title="America/Anchorage">America/Anchorage</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:US" title="ISO 3166-1:US">US</a>
# </td>
# <td>
# </td>
# <td><a class="mw-redirect" href="/wiki/America/Adak" title="America/Adak">US/Aleutian</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="-10"><a href="/wiki/UTC%E2%88%9210:00" title="UTC−10:00">−10:00</a>
# </td>
# <td data-sort-value="-9"><a href="/wiki/UTC%E2%88%9209:00" title="UTC−09:00">−09:00</a>
# </td>
# <td>Link to <a class="mw-redirect" href="/wiki/America/Adak" title="America/Adak">America/Adak</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:US" title="ISO 3166-1:US">US</a>
# </td>
# <td>
# </td>
# <td><a href="/wiki/Time_in_Arizona" title="Time in Arizona">US/Arizona</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="-7"><a href="/wiki/UTC%E2%88%9207:00" title="UTC−07:00">−07:00</a>
# </td>
# <td data-sort-value="-7"><a href="/wiki/UTC%E2%88%9207:00" title="UTC−07:00">−07:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=America/Phoenix&amp;action=edit&amp;redlink=1" title="America/Phoenix (page does not exist)">America/Phoenix</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:US" title="ISO 3166-1:US">US</a>
# </td>
# <td>
# </td>
# <td><a href="/wiki/Central_Time_Zone" title="Central Time Zone">US/Central</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="-6"><a href="/wiki/UTC%E2%88%9206:00" title="UTC−06:00">−06:00</a>
# </td>
# <td data-sort-value="-5"><a href="/wiki/UTC%E2%88%9205:00" title="UTC−05:00">−05:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=America/Chicago&amp;action=edit&amp;redlink=1" title="America/Chicago (page does not exist)">America/Chicago</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:US" title="ISO 3166-1:US">US</a>
# </td>
# <td>
# </td>
# <td><a href="/wiki/Time_in_Indiana" title="Time in Indiana">US/East-Indiana</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="-5"><a href="/wiki/UTC%E2%88%9205:00" title="UTC−05:00">−05:00</a>
# </td>
# <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=America/Indiana/Indianapolis&amp;action=edit&amp;redlink=1" title="America/Indiana/Indianapolis (page does not exist)">America/Indiana/Indianapolis</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:US" title="ISO 3166-1:US">US</a>
# </td>
# <td>
# </td>
# <td><a href="/wiki/Time_in_New_York" title="Time in New York">US/Eastern</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="-5"><a href="/wiki/UTC%E2%88%9205:00" title="UTC−05:00">−05:00</a>
# </td>
# <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
# </td>
# <td>Link to <a class="mw-redirect" href="/wiki/America/New_York" title="America/New York">America/New_York</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:US" title="ISO 3166-1:US">US</a>
# </td>
# <td>
# </td>
# <td><a href="/wiki/Time_in_Hawaii" title="Time in Hawaii">US/Hawaii</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="-10"><a href="/wiki/UTC%E2%88%9210:00" title="UTC−10:00">−10:00</a>
# </td>
# <td data-sort-value="-10"><a href="/wiki/UTC%E2%88%9210:00" title="UTC−10:00">−10:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Pacific/Honolulu&amp;action=edit&amp;redlink=1" title="Pacific/Honolulu (page does not exist)">Pacific/Honolulu</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:US" title="ISO 3166-1:US">US</a>
# </td>
# <td>
# </td>
# <td><a href="/wiki/Time_in_Indiana" title="Time in Indiana">US/Indiana-Starke</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="-6"><a href="/wiki/UTC%E2%88%9206:00" title="UTC−06:00">−06:00</a>
# </td>
# <td data-sort-value="-5"><a href="/wiki/UTC%E2%88%9205:00" title="UTC−05:00">−05:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=America/Indiana/Knox&amp;action=edit&amp;redlink=1" title="America/Indiana/Knox (page does not exist)">America/Indiana/Knox</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:US" title="ISO 3166-1:US">US</a>
# </td>
# <td>
# </td>
# <td><a href="/wiki/Time_in_Michigan" title="Time in Michigan">US/Michigan</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="-5"><a href="/wiki/UTC%E2%88%9205:00" title="UTC−05:00">−05:00</a>
# </td>
# <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=America/Detroit&amp;action=edit&amp;redlink=1" title="America/Detroit (page does not exist)">America/Detroit</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:US" title="ISO 3166-1:US">US</a>
# </td>
# <td>
# </td>
# <td><a href="/wiki/Mountain_Time_Zone" title="Mountain Time Zone">US/Mountain</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="-7"><a href="/wiki/UTC%E2%88%9207:00" title="UTC−07:00">−07:00</a>
# </td>
# <td data-sort-value="-6"><a href="/wiki/UTC%E2%88%9206:00" title="UTC−06:00">−06:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=America/Denver&amp;action=edit&amp;redlink=1" title="America/Denver (page does not exist)">America/Denver</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:US" title="ISO 3166-1:US">US</a>
# </td>
# <td>
# </td>
# <td><a href="/wiki/Pacific_Time_Zone" title="Pacific Time Zone">US/Pacific</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="-8"><a href="/wiki/UTC%E2%88%9208:00" title="UTC−08:00">−08:00</a>
# </td>
# <td data-sort-value="-7"><a href="/wiki/UTC%E2%88%9207:00" title="UTC−07:00">−07:00</a>
# </td>
# <td>Link to <a class="mw-redirect" href="/wiki/America/Los_Angeles" title="America/Los Angeles">America/Los_Angeles</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:WS" title="ISO 3166-1:WS">WS</a>
# </td>
# <td>
# </td>
# <td><a href="/wiki/Time_in_Samoa" title="Time in Samoa">US/Samoa</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="-11"><a href="/wiki/UTC%E2%88%9211:00" title="UTC−11:00">−11:00</a>
# </td>
# <td data-sort-value="-11"><a href="/wiki/UTC%E2%88%9211:00" title="UTC−11:00">−11:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Pacific/Pago_Pago&amp;action=edit&amp;redlink=1" title="Pacific/Pago Pago (page does not exist)">Pacific/Pago_Pago</a>
# </td></tr>
# <tr>
# <td>
# </td>
# <td>
# </td>
# <td><a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">UTC</a>
# </td>
# <td>
# </td>
# <td>Alias
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td>Link to <a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">Etc/UTC</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_3166-1:RU" title="ISO 3166-1:RU">RU</a>
# </td>
# <td>
# </td>
# <td><a href="/wiki/Moscow_Time" title="Moscow Time">W-SU</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
# </td>
# <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
# </td>
# <td>Link to <a class="new" href="/w/index.php?title=Europe/Moscow&amp;action=edit&amp;redlink=1" title="Europe/Moscow (page does not exist)">Europe/Moscow</a>
# </td></tr>
# <tr>
# <td>
# </td>
# <td>
# </td>
# <td><a href="/wiki/Western_European_Time" title="Western European Time">WET</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
# </td>
# <td>Choose a zone that <i>observes</i> WET, such as <a class="mw-redirect" href="/wiki/Europe/Lisbon" title="Europe/Lisbon">Europe/Lisbon</a>.
# </td></tr>
# <tr>
# <td>
# </td>
# <td>
# </td>
# <td><a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">Zulu</a>
# </td>
# <td>
# </td>
# <td>Deprecated
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
# </td>
# <td>Link to <a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">Etc/UTC</a>
# </td></tr></tbody></table>

# %%
headers = []
for header in table.find_all("th"):
    headerText = header.text.replace("\n", "")
    headers.append(headerText)

headers
# Out:
# ['Country code',
#  'Latitude, longitude ±DDMM(SS)±DDDMM(SS)',
#  'TZ database name',
#  'Portion of country covered',
#  'Status',
#  'UTC offset ±hh:mm',
#  'UTC DST offset ±hh:mm',
#  'Notes']

# %%
rows = []
for row in table.find_all("tr"):
    rows.append(row)
    
del rows[0]    

rows
# Out:
# [<tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:CI" title="ISO 3166-1:CI">CI</a>
#  </td>
#  <td>+0519−00402
#  </td>
#  <td><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">Africa/Abidjan</a>
#  </td>
#  <td>
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:GH" title="ISO 3166-1:GH">GH</a>
#  </td>
#  <td>+0533−00013
#  </td>
#  <td><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">Africa/Accra</a>
#  </td>
#  <td>
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:ET" title="ISO 3166-1:ET">ET</a>
#  </td>
#  <td>+0902+03842
#  </td>
#  <td><a href="/wiki/East_Africa_Time" title="East Africa Time">Africa/Addis_Ababa</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
#  </td>
#  <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
#  </td>
#  <td>Link to <a href="/wiki/East_Africa_Time" title="East Africa Time">Africa/Nairobi</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:DZ" title="ISO 3166-1:DZ">DZ</a>
#  </td>
#  <td>+3647+00303
#  </td>
#  <td><a href="/wiki/Central_European_Time" title="Central European Time">Africa/Algiers</a>
#  </td>
#  <td>
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:ER" title="ISO 3166-1:ER">ER</a>
#  </td>
#  <td>+1520+03853
#  </td>
#  <td><a href="/wiki/East_Africa_Time" title="East Africa Time">Africa/Asmara</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
#  </td>
#  <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
#  </td>
#  <td>Link to <a href="/wiki/East_Africa_Time" title="East Africa Time">Africa/Nairobi</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:ER" title="ISO 3166-1:ER">ER</a>
#  </td>
#  <td>+1520+03853
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Asmera&amp;action=edit&amp;redlink=1" title="Africa/Asmera (page does not exist)">Africa/Asmera</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
#  </td>
#  <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
#  </td>
#  <td>Link to <a href="/wiki/East_Africa_Time" title="East Africa Time">Africa/Nairobi</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:ML" title="ISO 3166-1:ML">ML</a>
#  </td>
#  <td>+1239−00800
#  </td>
#  <td><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">Africa/Bamako</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Abidjan</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:CF" title="ISO 3166-1:CF">CF</a>
#  </td>
#  <td>+0422+01835
#  </td>
#  <td><a href="/wiki/West_Africa_Time" title="West Africa Time">Africa/Bangui</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Lagos</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:GM" title="ISO 3166-1:GM">GM</a>
#  </td>
#  <td>+1328−01639
#  </td>
#  <td><a href="/wiki/Greenwich_Mean_Time" title="Greenwich Mean Time">Africa/Banjul</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Abidjan</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:GW" title="ISO 3166-1:GW">GW</a>
#  </td>
#  <td>+1151−01535
#  </td>
#  <td><a class="mw-redirect" href="/wiki/GMT" title="GMT">Africa/Bissau</a>
#  </td>
#  <td>
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:MW" title="ISO 3166-1:MW">MW</a>
#  </td>
#  <td>−1547+03500
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Blantyre</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Maputo</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:CG" title="ISO 3166-1:CG">CG</a>
#  </td>
#  <td>−0416+01517
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Brazzaville</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Lagos</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:BI" title="ISO 3166-1:BI">BI</a>
#  </td>
#  <td>−0323+02922
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Bujumbura</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Maputo</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:EG" title="ISO 3166-1:EG">EG</a>
#  </td>
#  <td>+3003+03115
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Cairo&amp;action=edit&amp;redlink=1" title="Africa/Cairo (page does not exist)">Africa/Cairo</a>
#  </td>
#  <td>
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:MA" title="ISO 3166-1:MA">MA</a>
#  </td>
#  <td>+3339−00735
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Casablanca&amp;action=edit&amp;redlink=1" title="Africa/Casablanca (page does not exist)">Africa/Casablanca</a>
#  </td>
#  <td>
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:ES" title="ISO 3166-1:ES">ES</a>
#  </td>
#  <td>+3553−00519
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Ceuta&amp;action=edit&amp;redlink=1" title="Africa/Ceuta (page does not exist)">Africa/Ceuta</a>
#  </td>
#  <td>Ceuta, Melilla
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:GN" title="ISO 3166-1:GN">GN</a>
#  </td>
#  <td>+0931−01343
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Conakry</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Abidjan</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:SN" title="ISO 3166-1:SN">SN</a>
#  </td>
#  <td>+1440−01726
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Dakar</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Abidjan</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:TZ" title="ISO 3166-1:TZ">TZ</a>
#  </td>
#  <td>−0648+03917
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Nairobi&amp;action=edit&amp;redlink=1" title="Africa/Nairobi (page does not exist)">Africa/Dar_es_Salaam</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
#  </td>
#  <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
#  </td>
#  <td>Link to <a href="/wiki/East_Africa_Time" title="East Africa Time">Africa/Nairobi</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:DJ" title="ISO 3166-1:DJ">DJ</a>
#  </td>
#  <td>+1136+04309
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Nairobi&amp;action=edit&amp;redlink=1" title="Africa/Nairobi (page does not exist)">Africa/Djibouti</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
#  </td>
#  <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
#  </td>
#  <td>Link to <a href="/wiki/East_Africa_Time" title="East Africa Time">Africa/Nairobi</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:CM" title="ISO 3166-1:CM">CM</a>
#  </td>
#  <td>+0403+00942
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Douala</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Lagos</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:EH" title="ISO 3166-1:EH">EH</a>
#  </td>
#  <td>+2709−01312
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/El_Aaiun&amp;action=edit&amp;redlink=1" title="Africa/El Aaiun (page does not exist)">Africa/El_Aaiun</a>
#  </td>
#  <td>
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:SL" title="ISO 3166-1:SL">SL</a>
#  </td>
#  <td>+0830−01315
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Freetown</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Abidjan</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:BW" title="ISO 3166-1:BW">BW</a>
#  </td>
#  <td>−2439+02555
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Gaborone</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Maputo</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:ZW" title="ISO 3166-1:ZW">ZW</a>
#  </td>
#  <td>−1750+03103
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Harare</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Maputo</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:ZA" title="ISO 3166-1:ZA">ZA</a>
#  </td>
#  <td>−2615+02800
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Johannesburg&amp;action=edit&amp;redlink=1" title="Africa/Johannesburg (page does not exist)">Africa/Johannesburg</a>
#  </td>
#  <td>
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:SS" title="ISO 3166-1:SS">SS</a>
#  </td>
#  <td>+0451+03137
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Juba&amp;action=edit&amp;redlink=1" title="Africa/Juba (page does not exist)">Africa/Juba</a>
#  </td>
#  <td>
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:UG" title="ISO 3166-1:UG">UG</a>
#  </td>
#  <td>+0019+03225
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Nairobi&amp;action=edit&amp;redlink=1" title="Africa/Nairobi (page does not exist)">Africa/Kampala</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
#  </td>
#  <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
#  </td>
#  <td>Link to <a href="/wiki/East_Africa_Time" title="East Africa Time">Africa/Nairobi</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:SD" title="ISO 3166-1:SD">SD</a>
#  </td>
#  <td>+1536+03232
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Khartoum&amp;action=edit&amp;redlink=1" title="Africa/Khartoum (page does not exist)">Africa/Khartoum</a>
#  </td>
#  <td>
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:RW" title="ISO 3166-1:RW">RW</a>
#  </td>
#  <td>−0157+03004
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Kigali</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Maputo</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:CD" title="ISO 3166-1:CD">CD</a>
#  </td>
#  <td>−0418+01518
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Kinshasa</a>
#  </td>
#  <td>Dem. Rep. of Congo (west)
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Lagos</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:NG" title="ISO 3166-1:NG">NG</a>
#  </td>
#  <td>+0627+00324
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Lagos</a>
#  </td>
#  <td>West Africa Time
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:GA" title="ISO 3166-1:GA">GA</a>
#  </td>
#  <td>+0023+00927
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Libreville</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Lagos</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:TG" title="ISO 3166-1:TG">TG</a>
#  </td>
#  <td>+0608+00113
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Lome</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Abidjan</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AO" title="ISO 3166-1:AO">AO</a>
#  </td>
#  <td>−0848+01314
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Luanda</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Lagos</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:CD" title="ISO 3166-1:CD">CD</a>
#  </td>
#  <td>−1140+02728
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Lubumbashi</a>
#  </td>
#  <td>Dem. Rep. of Congo (east)
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Maputo</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:ZM" title="ISO 3166-1:ZM">ZM</a>
#  </td>
#  <td>−1525+02817
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Lusaka</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Maputo</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:GQ" title="ISO 3166-1:GQ">GQ</a>
#  </td>
#  <td>+0345+00847
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Malabo</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Lagos</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:MZ" title="ISO 3166-1:MZ">MZ</a>
#  </td>
#  <td>−2558+03235
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Maputo&amp;action=edit&amp;redlink=1" title="Africa/Maputo (page does not exist)">Africa/Maputo</a>
#  </td>
#  <td>Central Africa Time
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:LS" title="ISO 3166-1:LS">LS</a>
#  </td>
#  <td>−2928+02730
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Johannesburg&amp;action=edit&amp;redlink=1" title="Africa/Johannesburg (page does not exist)">Africa/Maseru</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Africa/Johannesburg&amp;action=edit&amp;redlink=1" title="Africa/Johannesburg (page does not exist)">Africa/Johannesburg</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:SZ" title="ISO 3166-1:SZ">SZ</a>
#  </td>
#  <td>−2618+03106
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Johannesburg&amp;action=edit&amp;redlink=1" title="Africa/Johannesburg (page does not exist)">Africa/Mbabane</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Africa/Johannesburg&amp;action=edit&amp;redlink=1" title="Africa/Johannesburg (page does not exist)">Africa/Johannesburg</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:SO" title="ISO 3166-1:SO">SO</a>
#  </td>
#  <td>+0204+04522
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Nairobi&amp;action=edit&amp;redlink=1" title="Africa/Nairobi (page does not exist)">Africa/Mogadishu</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
#  </td>
#  <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
#  </td>
#  <td>Link to <a href="/wiki/East_Africa_Time" title="East Africa Time">Africa/Nairobi</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:LR" title="ISO 3166-1:LR">LR</a>
#  </td>
#  <td>+0618−01047
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Monrovia&amp;action=edit&amp;redlink=1" title="Africa/Monrovia (page does not exist)">Africa/Monrovia</a>
#  </td>
#  <td>
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:KE" title="ISO 3166-1:KE">KE</a>
#  </td>
#  <td>−0117+03649
#  </td>
#  <td><a href="/wiki/East_Africa_Time" title="East Africa Time">Africa/Nairobi</a>
#  </td>
#  <td>
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
#  </td>
#  <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:TD" title="ISO 3166-1:TD">TD</a>
#  </td>
#  <td>+1207+01503
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Ndjamena&amp;action=edit&amp;redlink=1" title="Africa/Ndjamena (page does not exist)">Africa/Ndjamena</a>
#  </td>
#  <td>
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:NE" title="ISO 3166-1:NE">NE</a>
#  </td>
#  <td>+1331+00207
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Niamey</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Lagos</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:MR" title="ISO 3166-1:MR">MR</a>
#  </td>
#  <td>+1806−01557
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Nouakchott</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Abidjan</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:BF" title="ISO 3166-1:BF">BF</a>
#  </td>
#  <td>+1222−00131
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Ouagadougou</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Abidjan</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:BJ" title="ISO 3166-1:BJ">BJ</a>
#  </td>
#  <td>+0629+00237
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Porto-Novo</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Africa/Lagos&amp;action=edit&amp;redlink=1" title="Africa/Lagos (page does not exist)">Africa/Lagos</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:ST" title="ISO 3166-1:ST">ST</a>
#  </td>
#  <td>+0020+00644
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Sao_Tome</a>
#  </td>
#  <td>
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:ML" title="ISO 3166-1:ML">ML</a>
#  </td>
#  <td>
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Timbuktu</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Africa/Abidjan&amp;action=edit&amp;redlink=1" title="Africa/Abidjan (page does not exist)">Africa/Abidjan</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:LY" title="ISO 3166-1:LY">LY</a>
#  </td>
#  <td>+3254+01311
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Tripoli&amp;action=edit&amp;redlink=1" title="Africa/Tripoli (page does not exist)">Africa/Tripoli</a>
#  </td>
#  <td>
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:TN" title="ISO 3166-1:TN">TN</a>
#  </td>
#  <td>+3648+01011
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Tunis&amp;action=edit&amp;redlink=1" title="Africa/Tunis (page does not exist)">Africa/Tunis</a>
#  </td>
#  <td>
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:NA" title="ISO 3166-1:NA">NA</a>
#  </td>
#  <td>−2234+01706
#  </td>
#  <td><a class="new" href="/w/index.php?title=Africa/Windhoek&amp;action=edit&amp;redlink=1" title="Africa/Windhoek (page does not exist)">Africa/Windhoek</a>
#  </td>
#  <td>
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:US" title="ISO 3166-1:US">US</a>
#  </td>
#  <td>+515248−1763929
#  </td>
#  <td><a class="mw-redirect" href="/wiki/America/Adak" title="America/Adak">America/Adak</a>
#  </td>
#  <td>Aleutian Islands
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="-10"><a href="/wiki/UTC%E2%88%9210:00" title="UTC−10:00">−10:00</a>
#  </td>
#  <td data-sort-value="-9"><a href="/wiki/UTC%E2%88%9209:00" title="UTC−09:00">−09:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:US" title="ISO 3166-1:US">US</a>
#  </td>
#  <td>+611305−1495401
#  </td>
#  <td><a class="mw-redirect" href="/wiki/America/Anchorage" title="America/Anchorage">America/Anchorage</a>
#  </td>
#  <td>Alaska (most areas)
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="-9"><a href="/wiki/UTC%E2%88%9209:00" title="UTC−09:00">−09:00</a>
#  </td>
#  <td data-sort-value="-8"><a href="/wiki/UTC%E2%88%9208:00" title="UTC−08:00">−08:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AI" title="ISO 3166-1:AI">AI</a>
#  </td>
#  <td>+1812−06304
#  </td>
#  <td><a class="mw-redirect" href="/wiki/America/Port_of_Spain" title="America/Port of Spain">America/Anguilla</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
#  </td>
#  <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
#  </td>
#  <td>Link to <a class="mw-redirect" href="/wiki/America/Port_of_Spain" title="America/Port of Spain">America/Port_of_Spain</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AG" title="ISO 3166-1:AG">AG</a>
#  </td>
#  <td>+1703−06148
#  </td>
#  <td><a class="mw-redirect" href="/wiki/America/Port_of_Spain" title="America/Port of Spain">America/Antigua</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
#  </td>
#  <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
#  </td>
#  <td>Link to <a class="mw-redirect" href="/wiki/America/Port_of_Spain" title="America/Port of Spain">America/Port_of_Spain</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:BR" title="ISO 3166-1:BR">BR</a>
#  </td>
#  <td>−0712−04812
#  </td>
#  <td><a class="new" href="/w/index.php?title=America/Araguaina&amp;action=edit&amp;redlink=1" title="America/Araguaina (page does not exist)">America/Araguaina</a>
#  </td>
#  <td>Tocantins
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AR" title="ISO 3166-1:AR">AR</a>
#  </td>
#  <td>−3436−05827
#  </td>
#  <td><a class="new" href="/w/index.php?title=America/Argentina/Buenos_Aires&amp;action=edit&amp;redlink=1" title="America/Argentina/Buenos Aires (page does not exist)">America/Argentina/Buenos_Aires</a>
#  </td>
#  <td>Buenos Aires (BA, CF)
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AR" title="ISO 3166-1:AR">AR</a>
#  </td>
#  <td>−2828−06547
#  </td>
#  <td><a class="new" href="/w/index.php?title=America/Argentina/Catamarca&amp;action=edit&amp;redlink=1" title="America/Argentina/Catamarca (page does not exist)">America/Argentina/Catamarca</a>
#  </td>
#  <td>Catamarca (CT); Chubut (CH)
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AR" title="ISO 3166-1:AR">AR</a>
#  </td>
#  <td>
#  </td>
#  <td><a class="new" href="/w/index.php?title=America/Argentina/Catamarca&amp;action=edit&amp;redlink=1" title="America/Argentina/Catamarca (page does not exist)">America/Argentina/ComodRivadavia</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=America/Argentina/Catamarca&amp;action=edit&amp;redlink=1" title="America/Argentina/Catamarca (page does not exist)">America/Argentina/Catamarca</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AR" title="ISO 3166-1:AR">AR</a>
#  </td>
#  <td>−3124−06411
#  </td>
#  <td><a class="new" href="/w/index.php?title=America/Argentina/Cordoba&amp;action=edit&amp;redlink=1" title="America/Argentina/Cordoba (page does not exist)">America/Argentina/Cordoba</a>
#  </td>
#  <td>Argentina (most areas: CB, CC, CN, ER, FM, MN, SE, SF)
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AR" title="ISO 3166-1:AR">AR</a>
#  </td>
#  <td>−2411−06518
#  </td>
#  <td><a class="new" href="/w/index.php?title=America/Argentina/Jujuy&amp;action=edit&amp;redlink=1" title="America/Argentina/Jujuy (page does not exist)">America/Argentina/Jujuy</a>
#  </td>
#  <td>Jujuy (JY)
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AR" title="ISO 3166-1:AR">AR</a>
#  </td>
#  <td>−2926−06651
#  </td>
#  <td><a class="new" href="/w/index.php?title=America/Argentina/La_Rioja&amp;action=edit&amp;redlink=1" title="America/Argentina/La Rioja (page does not exist)">America/Argentina/La_Rioja</a>
#  </td>
#  <td>La Rioja (LR)
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AR" title="ISO 3166-1:AR">AR</a>
#  </td>
#  <td>−3253−06849
#  </td>
#  <td><a class="new" href="/w/index.php?title=America/Argentina/Mendoza&amp;action=edit&amp;redlink=1" title="America/Argentina/Mendoza (page does not exist)">America/Argentina/Mendoza</a>
#  </td>
#  <td>Mendoza (MZ)
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AR" title="ISO 3166-1:AR">AR</a>
#  </td>
#  <td>−5138−06913
#  </td>
#  <td><a class="new" href="/w/index.php?title=America/Argentina/Rio_Gallegos&amp;action=edit&amp;redlink=1" title="America/Argentina/Rio Gallegos (page does not exist)">America/Argentina/Rio_Gallegos</a>
#  </td>
#  <td>Santa Cruz (SC)
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AR" title="ISO 3166-1:AR">AR</a>
#  </td>
#  <td>−2447−06525
#  </td>
#  <td><a class="new" href="/w/index.php?title=America/Argentina/Salta&amp;action=edit&amp;redlink=1" title="America/Argentina/Salta (page does not exist)">America/Argentina/Salta</a>
#  </td>
#  <td>Salta (SA, LP, NQ, RN)
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AR" title="ISO 3166-1:AR">AR</a>
#  </td>
#  <td>−3132−06831
#  </td>
#  <td><a class="new" href="/w/index.php?title=America/Argentina/San_Juan&amp;action=edit&amp;redlink=1" title="America/Argentina/San Juan (page does not exist)">America/Argentina/San_Juan</a>
#  </td>
#  <td>San Juan (SJ)
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AR" title="ISO 3166-1:AR">AR</a>
#  </td>
#  <td>−3319−06621
#  </td>
#  <td><a class="new" href="/w/index.php?title=America/Argentina/San_Luis&amp;action=edit&amp;redlink=1" title="America/Argentina/San Luis (page does not exist)">America/Argentina/San_Luis</a>
#  </td>
#  <td>San Luis (SL)
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AR" title="ISO 3166-1:AR">AR</a>
#  </td>
#  <td>−2649−06513
#  </td>
#  <td><a class="new" href="/w/index.php?title=America/Argentina/Tucuman&amp;action=edit&amp;redlink=1" title="America/Argentina/Tucuman (page does not exist)">America/Argentina/Tucuman</a>
#  </td>
#  <td>Tucumán (TM)
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AR" title="ISO 3166-1:AR">AR</a>
#  </td>
#  <td>−5448−06818
#  </td>
#  <td><a class="new" href="/w/index.php?title=America/Argentina/Ushuaia&amp;action=edit&amp;redlink=1" title="America/Argentina/Ushuaia (page does not exist)">America/Argentina/Ushuaia</a>
#  </td>
#  <td>Tierra del Fuego (TF)
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:AW" title="ISO 3166-1:AW">AW</a>
#  </td>
#  <td>+1230−06958
#  </td>
#  <td><a class="new" href="/w/index.php?title=America/Curacao&amp;action=edit&amp;redlink=1" title="America/Curacao (page does not exist)">America/Aruba</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
#  </td>
#  <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=America/Curacao&amp;action=edit&amp;redlink=1" title="America/Curacao (page does not exist)">America/Curacao</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:PY" title="ISO 3166-1:PY">PY</a>
#  </td>
#  <td>−2516−05740
#  </td>
#  <td><a class="new" href="/w/index.php?title=America/Asuncion&amp;action=edit&amp;redlink=1" title="America/Asuncion (page does not exist)">America/Asuncion</a>
#  </td>
#  <td>
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:CA" title="ISO 3166-1:CA">CA</a>
#  </td>
#  <td>+484531−0913718
#  </td>
#  <td><a class="new" href="/w/index.php?title=America/Atikokan&amp;action=edit&amp;redlink=1" title="America/Atikokan (page does not exist)">America/Atikokan</a>
#  </td>
#  <td>EST - ON (Atikokan); NU (Coral H)
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="-5"><a href="/wiki/UTC%E2%88%9205:00" title="UTC−05:00">−05:00</a>
#  </td>
#  <td data-sort-value="-5"><a href="/wiki/UTC%E2%88%9205:00" title="UTC−05:00">−05:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:US" title="ISO 3166-1:US">US</a>
#  </td>
#  <td>
#  </td>
#  <td><a class="mw-redirect" href="/wiki/America/Adak" title="America/Adak">America/Atka</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="-10"><a href="/wiki/UTC%E2%88%9210:00" title="UTC−10:00">−10:00</a>
#  </td>
#  <td data-sort-value="-9"><a href="/wiki/UTC%E2%88%9209:00" title="UTC−09:00">−09:00</a>
#  </td>
#  <td>Link to <a class="mw-redirect" href="/wiki/America/Adak" title="America/Adak">America/Adak</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:BR" title="ISO 3166-1:BR">BR</a>
#  </td>
#  <td>−1259−03831
#  </td>
#  <td><a class="new" href="/w/index.php?title=America/Bahia&amp;action=edit&amp;redlink=1" title="America/Bahia (page does not exist)">America/Bahia</a>
#  </td>
#  <td>Bahia
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:MX" title="ISO 3166-1:MX">MX</a>
#  </td>
#  <td>+2048−10515
#  </td>
#  <td><a class="new" href="/w/index.php?title=America/Bahia_Banderas&amp;action=edit&amp;redlink=1" title="America/Bahia Banderas (page does not exist)">America/Bahia_Banderas</a>
#  </td>
#  <td>Central Time - Bahía de Banderas
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="-6"><a href="/wiki/UTC%E2%88%9206:00" title="UTC−06:00">−06:00</a>
#  </td>
#  <td data-sort-value="-5"><a href="/wiki/UTC%E2%88%9205:00" title="UTC−05:00">−05:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:BB" title="ISO 3166-1:BB">BB</a>
#  </td>
#  <td>+1306−05937
#  </td>
#  <td><a class="new" href="/w/index.php?title=America/Barbados&amp;action=edit&amp;redlink=1" title="America/Barbados (page does not exist)">America/Barbados</a>
#  </td>
#  <td>
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
#  </td>
#  <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:BR" title="ISO 3166-1:BR">BR</a>
#  </td>
#  <td>−0127−04829
#  </td>
#  <td><a class="new" href="/w/index.php?title=America/Belem&amp;action=edit&amp;redlink=1" title="America/Belem (page does not exist)">America/Belem</a>
#  </td>
#  <td>Pará (east); Amapá
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td data-sort-value="-3"><a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">−03:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:BZ" title="ISO 3166-1:BZ">BZ</a>
#  </td>
#  <td>+1730−08812
#  </td>
#  <td><a class="new" href="/w/index.php?title=America/Belize&amp;action=edit&amp;redlink=1" title="America/Belize (page does not exist)">America/Belize</a>
#  </td>
#  <td>
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="-6"><a href="/wiki/UTC%E2%88%9206:00" title="UTC−06:00">−06:00</a>
#  </td>
#  <td data-sort-value="-6"><a href="/wiki/UTC%E2%88%9206:00" title="UTC−06:00">−06:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:CA" title="ISO 3166-1:CA">CA</a>
#  </td>
#  <td>+5125−05707
#  </td>
#  <td><a class="new" href="/w/index.php?title=America/Blanc-Sablon&amp;action=edit&amp;redlink=1" title="America/Blanc-Sablon (page does not exist)">America/Blanc-Sablon</a>
#  </td>
#  <td>AST - QC (Lower North Shore)
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
#  </td>
#  <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
# ...
#  </td>
#  <td>Wake Island
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="12"><a href="/wiki/UTC%2B12:00" title="UTC+12:00">+12:00</a>
#  </td>
#  <td data-sort-value="12"><a href="/wiki/UTC%2B12:00" title="UTC+12:00">+12:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:WF" title="ISO 3166-1:WF">WF</a>
#  </td>
#  <td>−1318−17610
#  </td>
#  <td><a class="new" href="/w/index.php?title=Pacific/Wallis&amp;action=edit&amp;redlink=1" title="Pacific/Wallis (page does not exist)">Pacific/Wallis</a>
#  </td>
#  <td>
#  </td>
#  <td>Canonical
#  </td>
#  <td data-sort-value="12"><a href="/wiki/UTC%2B12:00" title="UTC+12:00">+12:00</a>
#  </td>
#  <td data-sort-value="12"><a href="/wiki/UTC%2B12:00" title="UTC+12:00">+12:00</a>
#  </td>
#  <td>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:FM" title="ISO 3166-1:FM">FM</a>
#  </td>
#  <td>
#  </td>
#  <td><a class="new" href="/w/index.php?title=Pacific/Chuuk&amp;action=edit&amp;redlink=1" title="Pacific/Chuuk (page does not exist)">Pacific/Yap</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="10"><a href="/wiki/UTC%2B10:00" title="UTC+10:00">+10:00</a>
#  </td>
#  <td data-sort-value="10"><a href="/wiki/UTC%2B10:00" title="UTC+10:00">+10:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Pacific/Chuuk&amp;action=edit&amp;redlink=1" title="Pacific/Chuuk (page does not exist)">Pacific/Chuuk</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:PL" title="ISO 3166-1:PL">PL</a>
#  </td>
#  <td>
#  </td>
#  <td><a class="new" href="/w/index.php?title=Europe/Warsaw&amp;action=edit&amp;redlink=1" title="Europe/Warsaw (page does not exist)">Poland</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td data-sort-value="2"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">+02:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Europe/Warsaw&amp;action=edit&amp;redlink=1" title="Europe/Warsaw (page does not exist)">Europe/Warsaw</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:PT" title="ISO 3166-1:PT">PT</a>
#  </td>
#  <td>
#  </td>
#  <td><a class="mw-redirect" href="/wiki/Europe/Lisbon" title="Europe/Lisbon">Portugal</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td>Link to <a class="mw-redirect" href="/wiki/Europe/Lisbon" title="Europe/Lisbon">Europe/Lisbon</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:CN" title="ISO 3166-1:CN">CN</a>
#  </td>
#  <td>
#  </td>
#  <td><a class="mw-redirect" href="/wiki/Asia/Shanghai" title="Asia/Shanghai">PRC</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="8"><a href="/wiki/UTC%2B08:00" title="UTC+08:00">+08:00</a>
#  </td>
#  <td data-sort-value="8"><a href="/wiki/UTC%2B08:00" title="UTC+08:00">+08:00</a>
#  </td>
#  <td>Link to <a class="mw-redirect" href="/wiki/Asia/Shanghai" title="Asia/Shanghai">Asia/Shanghai</a>
#  </td></tr>, <tr>
#  <td>
#  </td>
#  <td>
#  </td>
#  <td><a class="mw-redirect" href="/wiki/PST8PDT" title="PST8PDT">PST8PDT</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="-8"><a href="/wiki/UTC%E2%88%9208:00" title="UTC−08:00">−08:00</a>
#  </td>
#  <td data-sort-value="-7"><a href="/wiki/UTC%E2%88%9207:00" title="UTC−07:00">−07:00</a>
#  </td>
#  <td>Choose a zone that <i>observes</i> PST with United States daylight saving time rules, such as <a class="mw-redirect" href="/wiki/America/Los_Angeles" title="America/Los Angeles">America/Los_Angeles</a>.
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:TW" title="ISO 3166-1:TW">TW</a>
#  </td>
#  <td>
#  </td>
#  <td><a class="mw-redirect" href="/wiki/Asia/Taipei" title="Asia/Taipei">ROC</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="8"><a href="/wiki/UTC%2B08:00" title="UTC+08:00">+08:00</a>
#  </td>
#  <td data-sort-value="8"><a href="/wiki/UTC%2B08:00" title="UTC+08:00">+08:00</a>
#  </td>
#  <td>Link to <a class="mw-redirect" href="/wiki/Asia/Taipei" title="Asia/Taipei">Asia/Taipei</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:KR" title="ISO 3166-1:KR">KR</a>
#  </td>
#  <td>
#  </td>
#  <td><a href="/wiki/Time_in_South_Korea" title="Time in South Korea">ROK</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="9"><a href="/wiki/UTC%2B09:00" title="UTC+09:00">+09:00</a>
#  </td>
#  <td data-sort-value="9"><a href="/wiki/UTC%2B09:00" title="UTC+09:00">+09:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Asia/Seoul&amp;action=edit&amp;redlink=1" title="Asia/Seoul (page does not exist)">Asia/Seoul</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:SG" title="ISO 3166-1:SG">SG</a>
#  </td>
#  <td>+0117+10351
#  </td>
#  <td><a class="mw-redirect" href="/wiki/Asia/Singapore" title="Asia/Singapore">Singapore</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="8"><a href="/wiki/UTC%2B08:00" title="UTC+08:00">+08:00</a>
#  </td>
#  <td data-sort-value="8"><a href="/wiki/UTC%2B08:00" title="UTC+08:00">+08:00</a>
#  </td>
#  <td>Link to <a class="mw-redirect" href="/wiki/Asia/Singapore" title="Asia/Singapore">Asia/Singapore</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:TR" title="ISO 3166-1:TR">TR</a>
#  </td>
#  <td>
#  </td>
#  <td><a href="/wiki/Time_in_Turkey" title="Time in Turkey">Turkey</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
#  </td>
#  <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Europe/Istanbul&amp;action=edit&amp;redlink=1" title="Europe/Istanbul (page does not exist)">Europe/Istanbul</a>
#  </td></tr>, <tr>
#  <td>
#  </td>
#  <td>
#  </td>
#  <td><a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">UCT</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td>Link to <a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">Etc/UTC</a>
#  </td></tr>, <tr>
#  <td>
#  </td>
#  <td>
#  </td>
#  <td><a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">Universal</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td>Link to <a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">Etc/UTC</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:US" title="ISO 3166-1:US">US</a>
#  </td>
#  <td>
#  </td>
#  <td><a class="mw-redirect" href="/wiki/America/Anchorage" title="America/Anchorage">US/Alaska</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="-9"><a href="/wiki/UTC%E2%88%9209:00" title="UTC−09:00">−09:00</a>
#  </td>
#  <td data-sort-value="-8"><a href="/wiki/UTC%E2%88%9208:00" title="UTC−08:00">−08:00</a>
#  </td>
#  <td>Link to <a class="mw-redirect" href="/wiki/America/Anchorage" title="America/Anchorage">America/Anchorage</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:US" title="ISO 3166-1:US">US</a>
#  </td>
#  <td>
#  </td>
#  <td><a class="mw-redirect" href="/wiki/America/Adak" title="America/Adak">US/Aleutian</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="-10"><a href="/wiki/UTC%E2%88%9210:00" title="UTC−10:00">−10:00</a>
#  </td>
#  <td data-sort-value="-9"><a href="/wiki/UTC%E2%88%9209:00" title="UTC−09:00">−09:00</a>
#  </td>
#  <td>Link to <a class="mw-redirect" href="/wiki/America/Adak" title="America/Adak">America/Adak</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:US" title="ISO 3166-1:US">US</a>
#  </td>
#  <td>
#  </td>
#  <td><a href="/wiki/Time_in_Arizona" title="Time in Arizona">US/Arizona</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="-7"><a href="/wiki/UTC%E2%88%9207:00" title="UTC−07:00">−07:00</a>
#  </td>
#  <td data-sort-value="-7"><a href="/wiki/UTC%E2%88%9207:00" title="UTC−07:00">−07:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=America/Phoenix&amp;action=edit&amp;redlink=1" title="America/Phoenix (page does not exist)">America/Phoenix</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:US" title="ISO 3166-1:US">US</a>
#  </td>
#  <td>
#  </td>
#  <td><a href="/wiki/Central_Time_Zone" title="Central Time Zone">US/Central</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="-6"><a href="/wiki/UTC%E2%88%9206:00" title="UTC−06:00">−06:00</a>
#  </td>
#  <td data-sort-value="-5"><a href="/wiki/UTC%E2%88%9205:00" title="UTC−05:00">−05:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=America/Chicago&amp;action=edit&amp;redlink=1" title="America/Chicago (page does not exist)">America/Chicago</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:US" title="ISO 3166-1:US">US</a>
#  </td>
#  <td>
#  </td>
#  <td><a href="/wiki/Time_in_Indiana" title="Time in Indiana">US/East-Indiana</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="-5"><a href="/wiki/UTC%E2%88%9205:00" title="UTC−05:00">−05:00</a>
#  </td>
#  <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=America/Indiana/Indianapolis&amp;action=edit&amp;redlink=1" title="America/Indiana/Indianapolis (page does not exist)">America/Indiana/Indianapolis</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:US" title="ISO 3166-1:US">US</a>
#  </td>
#  <td>
#  </td>
#  <td><a href="/wiki/Time_in_New_York" title="Time in New York">US/Eastern</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="-5"><a href="/wiki/UTC%E2%88%9205:00" title="UTC−05:00">−05:00</a>
#  </td>
#  <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
#  </td>
#  <td>Link to <a class="mw-redirect" href="/wiki/America/New_York" title="America/New York">America/New_York</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:US" title="ISO 3166-1:US">US</a>
#  </td>
#  <td>
#  </td>
#  <td><a href="/wiki/Time_in_Hawaii" title="Time in Hawaii">US/Hawaii</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="-10"><a href="/wiki/UTC%E2%88%9210:00" title="UTC−10:00">−10:00</a>
#  </td>
#  <td data-sort-value="-10"><a href="/wiki/UTC%E2%88%9210:00" title="UTC−10:00">−10:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Pacific/Honolulu&amp;action=edit&amp;redlink=1" title="Pacific/Honolulu (page does not exist)">Pacific/Honolulu</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:US" title="ISO 3166-1:US">US</a>
#  </td>
#  <td>
#  </td>
#  <td><a href="/wiki/Time_in_Indiana" title="Time in Indiana">US/Indiana-Starke</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="-6"><a href="/wiki/UTC%E2%88%9206:00" title="UTC−06:00">−06:00</a>
#  </td>
#  <td data-sort-value="-5"><a href="/wiki/UTC%E2%88%9205:00" title="UTC−05:00">−05:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=America/Indiana/Knox&amp;action=edit&amp;redlink=1" title="America/Indiana/Knox (page does not exist)">America/Indiana/Knox</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:US" title="ISO 3166-1:US">US</a>
#  </td>
#  <td>
#  </td>
#  <td><a href="/wiki/Time_in_Michigan" title="Time in Michigan">US/Michigan</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="-5"><a href="/wiki/UTC%E2%88%9205:00" title="UTC−05:00">−05:00</a>
#  </td>
#  <td data-sort-value="-4"><a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">−04:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=America/Detroit&amp;action=edit&amp;redlink=1" title="America/Detroit (page does not exist)">America/Detroit</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:US" title="ISO 3166-1:US">US</a>
#  </td>
#  <td>
#  </td>
#  <td><a href="/wiki/Mountain_Time_Zone" title="Mountain Time Zone">US/Mountain</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="-7"><a href="/wiki/UTC%E2%88%9207:00" title="UTC−07:00">−07:00</a>
#  </td>
#  <td data-sort-value="-6"><a href="/wiki/UTC%E2%88%9206:00" title="UTC−06:00">−06:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=America/Denver&amp;action=edit&amp;redlink=1" title="America/Denver (page does not exist)">America/Denver</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:US" title="ISO 3166-1:US">US</a>
#  </td>
#  <td>
#  </td>
#  <td><a href="/wiki/Pacific_Time_Zone" title="Pacific Time Zone">US/Pacific</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="-8"><a href="/wiki/UTC%E2%88%9208:00" title="UTC−08:00">−08:00</a>
#  </td>
#  <td data-sort-value="-7"><a href="/wiki/UTC%E2%88%9207:00" title="UTC−07:00">−07:00</a>
#  </td>
#  <td>Link to <a class="mw-redirect" href="/wiki/America/Los_Angeles" title="America/Los Angeles">America/Los_Angeles</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:WS" title="ISO 3166-1:WS">WS</a>
#  </td>
#  <td>
#  </td>
#  <td><a href="/wiki/Time_in_Samoa" title="Time in Samoa">US/Samoa</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="-11"><a href="/wiki/UTC%E2%88%9211:00" title="UTC−11:00">−11:00</a>
#  </td>
#  <td data-sort-value="-11"><a href="/wiki/UTC%E2%88%9211:00" title="UTC−11:00">−11:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Pacific/Pago_Pago&amp;action=edit&amp;redlink=1" title="Pacific/Pago Pago (page does not exist)">Pacific/Pago_Pago</a>
#  </td></tr>, <tr>
#  <td>
#  </td>
#  <td>
#  </td>
#  <td><a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">UTC</a>
#  </td>
#  <td>
#  </td>
#  <td>Alias
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td>Link to <a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">Etc/UTC</a>
#  </td></tr>, <tr>
#  <td><a class="mw-redirect" href="/wiki/ISO_3166-1:RU" title="ISO 3166-1:RU">RU</a>
#  </td>
#  <td>
#  </td>
#  <td><a href="/wiki/Moscow_Time" title="Moscow Time">W-SU</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
#  </td>
#  <td data-sort-value="3"><a href="/wiki/UTC%2B03:00" title="UTC+03:00">+03:00</a>
#  </td>
#  <td>Link to <a class="new" href="/w/index.php?title=Europe/Moscow&amp;action=edit&amp;redlink=1" title="Europe/Moscow (page does not exist)">Europe/Moscow</a>
#  </td></tr>, <tr>
#  <td>
#  </td>
#  <td>
#  </td>
#  <td><a href="/wiki/Western_European_Time" title="Western European Time">WET</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td data-sort-value="1"><a href="/wiki/UTC%2B01:00" title="UTC+01:00">+01:00</a>
#  </td>
#  <td>Choose a zone that <i>observes</i> WET, such as <a class="mw-redirect" href="/wiki/Europe/Lisbon" title="Europe/Lisbon">Europe/Lisbon</a>.
#  </td></tr>, <tr>
#  <td>
#  </td>
#  <td>
#  </td>
#  <td><a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">Zulu</a>
#  </td>
#  <td>
#  </td>
#  <td>Deprecated
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td data-sort-value="0"><a href="/wiki/UTC%C2%B100:00" title="UTC±00:00">+00:00</a>
#  </td>
#  <td>Link to <a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">Etc/UTC</a>
#  </td></tr>]

# %%
data = []

for row in rows:
    dataSet = {}
    i = 0
    for column in row.find_all("td"):
        columnText = column.text.replace("\n", "")
        dataSet[headers[i]] = columnText
        i += 1
        
    data.append(dataSet)
    
data
# Out:
# [{'Country code': 'CI',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0519−00402',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'Africa/Abidjan',
#   'UTC DST offset ±hh:mm': '+00:00',
#   'UTC offset ±hh:mm': '+00:00'},
#  {'Country code': 'GH',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0533−00013',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'Africa/Accra',
#   'UTC DST offset ±hh:mm': '+00:00',
#   'UTC offset ±hh:mm': '+00:00'},
#  {'Country code': 'ET',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0902+03842',
#   'Notes': 'Link to Africa/Nairobi',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Addis_Ababa',
#   'UTC DST offset ±hh:mm': '+03:00',
#   'UTC offset ±hh:mm': '+03:00'},
#  {'Country code': 'DZ',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+3647+00303',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'Africa/Algiers',
#   'UTC DST offset ±hh:mm': '+01:00',
#   'UTC offset ±hh:mm': '+01:00'},
#  {'Country code': 'ER',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1520+03853',
#   'Notes': 'Link to Africa/Nairobi',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Asmara',
#   'UTC DST offset ±hh:mm': '+03:00',
#   'UTC offset ±hh:mm': '+03:00'},
#  {'Country code': 'ER',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1520+03853',
#   'Notes': 'Link to Africa/Nairobi',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'Africa/Asmera',
#   'UTC DST offset ±hh:mm': '+03:00',
#   'UTC offset ±hh:mm': '+03:00'},
#  {'Country code': 'ML',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1239−00800',
#   'Notes': 'Link to Africa/Abidjan',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Bamako',
#   'UTC DST offset ±hh:mm': '+00:00',
#   'UTC offset ±hh:mm': '+00:00'},
#  {'Country code': 'CF',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0422+01835',
#   'Notes': 'Link to Africa/Lagos',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Bangui',
#   'UTC DST offset ±hh:mm': '+01:00',
#   'UTC offset ±hh:mm': '+01:00'},
#  {'Country code': 'GM',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1328−01639',
#   'Notes': 'Link to Africa/Abidjan',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Banjul',
#   'UTC DST offset ±hh:mm': '+00:00',
#   'UTC offset ±hh:mm': '+00:00'},
#  {'Country code': 'GW',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1151−01535',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'Africa/Bissau',
#   'UTC DST offset ±hh:mm': '+00:00',
#   'UTC offset ±hh:mm': '+00:00'},
#  {'Country code': 'MW',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−1547+03500',
#   'Notes': 'Link to Africa/Maputo',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Blantyre',
#   'UTC DST offset ±hh:mm': '+02:00',
#   'UTC offset ±hh:mm': '+02:00'},
#  {'Country code': 'CG',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−0416+01517',
#   'Notes': 'Link to Africa/Lagos',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Brazzaville',
#   'UTC DST offset ±hh:mm': '+01:00',
#   'UTC offset ±hh:mm': '+01:00'},
#  {'Country code': 'BI',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−0323+02922',
#   'Notes': 'Link to Africa/Maputo',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Bujumbura',
#   'UTC DST offset ±hh:mm': '+02:00',
#   'UTC offset ±hh:mm': '+02:00'},
#  {'Country code': 'EG',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+3003+03115',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'Africa/Cairo',
#   'UTC DST offset ±hh:mm': '+02:00',
#   'UTC offset ±hh:mm': '+02:00'},
#  {'Country code': 'MA',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+3339−00735',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'Africa/Casablanca',
#   'UTC DST offset ±hh:mm': '+00:00',
#   'UTC offset ±hh:mm': '+01:00'},
#  {'Country code': 'ES',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+3553−00519',
#   'Notes': '',
#   'Portion of country covered': 'Ceuta, Melilla',
#   'Status': 'Canonical',
#   'TZ database name': 'Africa/Ceuta',
#   'UTC DST offset ±hh:mm': '+02:00',
#   'UTC offset ±hh:mm': '+01:00'},
#  {'Country code': 'GN',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0931−01343',
#   'Notes': 'Link to Africa/Abidjan',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Conakry',
#   'UTC DST offset ±hh:mm': '+00:00',
#   'UTC offset ±hh:mm': '+00:00'},
#  {'Country code': 'SN',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1440−01726',
#   'Notes': 'Link to Africa/Abidjan',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Dakar',
#   'UTC DST offset ±hh:mm': '+00:00',
#   'UTC offset ±hh:mm': '+00:00'},
#  {'Country code': 'TZ',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−0648+03917',
#   'Notes': 'Link to Africa/Nairobi',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Dar_es_Salaam',
#   'UTC DST offset ±hh:mm': '+03:00',
#   'UTC offset ±hh:mm': '+03:00'},
#  {'Country code': 'DJ',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1136+04309',
#   'Notes': 'Link to Africa/Nairobi',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Djibouti',
#   'UTC DST offset ±hh:mm': '+03:00',
#   'UTC offset ±hh:mm': '+03:00'},
#  {'Country code': 'CM',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0403+00942',
#   'Notes': 'Link to Africa/Lagos',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Douala',
#   'UTC DST offset ±hh:mm': '+01:00',
#   'UTC offset ±hh:mm': '+01:00'},
#  {'Country code': 'EH',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+2709−01312',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'Africa/El_Aaiun',
#   'UTC DST offset ±hh:mm': '+00:00',
#   'UTC offset ±hh:mm': '+01:00'},
#  {'Country code': 'SL',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0830−01315',
#   'Notes': 'Link to Africa/Abidjan',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Freetown',
#   'UTC DST offset ±hh:mm': '+00:00',
#   'UTC offset ±hh:mm': '+00:00'},
#  {'Country code': 'BW',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−2439+02555',
#   'Notes': 'Link to Africa/Maputo',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Gaborone',
#   'UTC DST offset ±hh:mm': '+02:00',
#   'UTC offset ±hh:mm': '+02:00'},
#  {'Country code': 'ZW',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−1750+03103',
#   'Notes': 'Link to Africa/Maputo',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Harare',
#   'UTC DST offset ±hh:mm': '+02:00',
#   'UTC offset ±hh:mm': '+02:00'},
#  {'Country code': 'ZA',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−2615+02800',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'Africa/Johannesburg',
#   'UTC DST offset ±hh:mm': '+02:00',
#   'UTC offset ±hh:mm': '+02:00'},
#  {'Country code': 'SS',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0451+03137',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'Africa/Juba',
#   'UTC DST offset ±hh:mm': '+02:00',
#   'UTC offset ±hh:mm': '+02:00'},
#  {'Country code': 'UG',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0019+03225',
#   'Notes': 'Link to Africa/Nairobi',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Kampala',
#   'UTC DST offset ±hh:mm': '+03:00',
#   'UTC offset ±hh:mm': '+03:00'},
#  {'Country code': 'SD',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1536+03232',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'Africa/Khartoum',
#   'UTC DST offset ±hh:mm': '+02:00',
#   'UTC offset ±hh:mm': '+02:00'},
#  {'Country code': 'RW',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−0157+03004',
#   'Notes': 'Link to Africa/Maputo',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Kigali',
#   'UTC DST offset ±hh:mm': '+02:00',
#   'UTC offset ±hh:mm': '+02:00'},
#  {'Country code': 'CD',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−0418+01518',
#   'Notes': 'Link to Africa/Lagos',
#   'Portion of country covered': 'Dem. Rep. of Congo (west)',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Kinshasa',
#   'UTC DST offset ±hh:mm': '+01:00',
#   'UTC offset ±hh:mm': '+01:00'},
#  {'Country code': 'NG',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0627+00324',
#   'Notes': '',
#   'Portion of country covered': 'West Africa Time',
#   'Status': 'Canonical',
#   'TZ database name': 'Africa/Lagos',
#   'UTC DST offset ±hh:mm': '+01:00',
#   'UTC offset ±hh:mm': '+01:00'},
#  {'Country code': 'GA',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0023+00927',
#   'Notes': 'Link to Africa/Lagos',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Libreville',
#   'UTC DST offset ±hh:mm': '+01:00',
#   'UTC offset ±hh:mm': '+01:00'},
#  {'Country code': 'TG',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0608+00113',
#   'Notes': 'Link to Africa/Abidjan',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Lome',
#   'UTC DST offset ±hh:mm': '+00:00',
#   'UTC offset ±hh:mm': '+00:00'},
#  {'Country code': 'AO',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−0848+01314',
#   'Notes': 'Link to Africa/Lagos',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Luanda',
#   'UTC DST offset ±hh:mm': '+01:00',
#   'UTC offset ±hh:mm': '+01:00'},
#  {'Country code': 'CD',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−1140+02728',
#   'Notes': 'Link to Africa/Maputo',
#   'Portion of country covered': 'Dem. Rep. of Congo (east)',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Lubumbashi',
#   'UTC DST offset ±hh:mm': '+02:00',
#   'UTC offset ±hh:mm': '+02:00'},
#  {'Country code': 'ZM',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−1525+02817',
#   'Notes': 'Link to Africa/Maputo',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Lusaka',
#   'UTC DST offset ±hh:mm': '+02:00',
#   'UTC offset ±hh:mm': '+02:00'},
#  {'Country code': 'GQ',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0345+00847',
#   'Notes': 'Link to Africa/Lagos',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Malabo',
#   'UTC DST offset ±hh:mm': '+01:00',
#   'UTC offset ±hh:mm': '+01:00'},
#  {'Country code': 'MZ',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−2558+03235',
#   'Notes': '',
#   'Portion of country covered': 'Central Africa Time',
#   'Status': 'Canonical',
#   'TZ database name': 'Africa/Maputo',
#   'UTC DST offset ±hh:mm': '+02:00',
#   'UTC offset ±hh:mm': '+02:00'},
#  {'Country code': 'LS',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−2928+02730',
#   'Notes': 'Link to Africa/Johannesburg',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Maseru',
#   'UTC DST offset ±hh:mm': '+02:00',
#   'UTC offset ±hh:mm': '+02:00'},
#  {'Country code': 'SZ',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−2618+03106',
#   'Notes': 'Link to Africa/Johannesburg',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Mbabane',
#   'UTC DST offset ±hh:mm': '+02:00',
#   'UTC offset ±hh:mm': '+02:00'},
#  {'Country code': 'SO',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0204+04522',
#   'Notes': 'Link to Africa/Nairobi',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Mogadishu',
#   'UTC DST offset ±hh:mm': '+03:00',
#   'UTC offset ±hh:mm': '+03:00'},
#  {'Country code': 'LR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0618−01047',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'Africa/Monrovia',
#   'UTC DST offset ±hh:mm': '+00:00',
#   'UTC offset ±hh:mm': '+00:00'},
#  {'Country code': 'KE',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−0117+03649',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'Africa/Nairobi',
#   'UTC DST offset ±hh:mm': '+03:00',
#   'UTC offset ±hh:mm': '+03:00'},
#  {'Country code': 'TD',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1207+01503',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'Africa/Ndjamena',
#   'UTC DST offset ±hh:mm': '+01:00',
#   'UTC offset ±hh:mm': '+01:00'},
#  {'Country code': 'NE',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1331+00207',
#   'Notes': 'Link to Africa/Lagos',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Niamey',
#   'UTC DST offset ±hh:mm': '+01:00',
#   'UTC offset ±hh:mm': '+01:00'},
#  {'Country code': 'MR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1806−01557',
#   'Notes': 'Link to Africa/Abidjan',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Nouakchott',
#   'UTC DST offset ±hh:mm': '+00:00',
#   'UTC offset ±hh:mm': '+00:00'},
#  {'Country code': 'BF',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1222−00131',
#   'Notes': 'Link to Africa/Abidjan',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Ouagadougou',
#   'UTC DST offset ±hh:mm': '+00:00',
#   'UTC offset ±hh:mm': '+00:00'},
#  {'Country code': 'BJ',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0629+00237',
#   'Notes': 'Link to Africa/Lagos',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Africa/Porto-Novo',
#   'UTC DST offset ±hh:mm': '+01:00',
#   'UTC offset ±hh:mm': '+01:00'},
#  {'Country code': 'ST',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0020+00644',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'Africa/Sao_Tome',
#   'UTC DST offset ±hh:mm': '+00:00',
#   'UTC offset ±hh:mm': '+00:00'},
#  {'Country code': 'ML',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to Africa/Abidjan',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'Africa/Timbuktu',
#   'UTC DST offset ±hh:mm': '+00:00',
#   'UTC offset ±hh:mm': '+00:00'},
#  {'Country code': 'LY',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+3254+01311',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'Africa/Tripoli',
#   'UTC DST offset ±hh:mm': '+02:00',
#   'UTC offset ±hh:mm': '+02:00'},
#  {'Country code': 'TN',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+3648+01011',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'Africa/Tunis',
#   'UTC DST offset ±hh:mm': '+01:00',
#   'UTC offset ±hh:mm': '+01:00'},
#  {'Country code': 'NA',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−2234+01706',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'Africa/Windhoek',
#   'UTC DST offset ±hh:mm': '+02:00',
#   'UTC offset ±hh:mm': '+02:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+515248−1763929',
#   'Notes': '',
#   'Portion of country covered': 'Aleutian Islands',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Adak',
#   'UTC DST offset ±hh:mm': '−09:00',
#   'UTC offset ±hh:mm': '−10:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+611305−1495401',
#   'Notes': '',
#   'Portion of country covered': 'Alaska (most areas)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Anchorage',
#   'UTC DST offset ±hh:mm': '−08:00',
#   'UTC offset ±hh:mm': '−09:00'},
#  {'Country code': 'AI',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1812−06304',
#   'Notes': 'Link to America/Port_of_Spain',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'America/Anguilla',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−04:00'},
#  {'Country code': 'AG',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1703−06148',
#   'Notes': 'Link to America/Port_of_Spain',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'America/Antigua',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−04:00'},
#  {'Country code': 'BR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−0712−04812',
#   'Notes': '',
#   'Portion of country covered': 'Tocantins',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Araguaina',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−03:00'},
#  {'Country code': 'AR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−3436−05827',
#   'Notes': '',
#   'Portion of country covered': 'Buenos Aires (BA, CF)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Argentina/Buenos_Aires',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−03:00'},
#  {'Country code': 'AR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−2828−06547',
#   'Notes': '',
#   'Portion of country covered': 'Catamarca (CT); Chubut (CH)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Argentina/Catamarca',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−03:00'},
#  {'Country code': 'AR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to America/Argentina/Catamarca',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'America/Argentina/ComodRivadavia',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−03:00'},
#  {'Country code': 'AR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−3124−06411',
#   'Notes': '',
#   'Portion of country covered': 'Argentina (most areas: CB, CC, CN, ER, FM, MN, SE, SF)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Argentina/Cordoba',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−03:00'},
#  {'Country code': 'AR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−2411−06518',
#   'Notes': '',
#   'Portion of country covered': 'Jujuy (JY)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Argentina/Jujuy',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−03:00'},
#  {'Country code': 'AR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−2926−06651',
#   'Notes': '',
#   'Portion of country covered': 'La Rioja (LR)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Argentina/La_Rioja',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−03:00'},
#  {'Country code': 'AR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−3253−06849',
#   'Notes': '',
#   'Portion of country covered': 'Mendoza (MZ)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Argentina/Mendoza',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−03:00'},
#  {'Country code': 'AR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−5138−06913',
#   'Notes': '',
#   'Portion of country covered': 'Santa Cruz (SC)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Argentina/Rio_Gallegos',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−03:00'},
#  {'Country code': 'AR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−2447−06525',
#   'Notes': '',
#   'Portion of country covered': 'Salta (SA, LP, NQ, RN)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Argentina/Salta',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−03:00'},
#  {'Country code': 'AR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−3132−06831',
#   'Notes': '',
#   'Portion of country covered': 'San Juan (SJ)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Argentina/San_Juan',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−03:00'},
#  {'Country code': 'AR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−3319−06621',
#   'Notes': '',
#   'Portion of country covered': 'San Luis (SL)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Argentina/San_Luis',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−03:00'},
#  {'Country code': 'AR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−2649−06513',
#   'Notes': '',
#   'Portion of country covered': 'Tucumán (TM)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Argentina/Tucuman',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−03:00'},
#  {'Country code': 'AR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−5448−06818',
#   'Notes': '',
#   'Portion of country covered': 'Tierra del Fuego (TF)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Argentina/Ushuaia',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−03:00'},
#  {'Country code': 'AW',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1230−06958',
#   'Notes': 'Link to America/Curacao',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'America/Aruba',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−04:00'},
#  {'Country code': 'PY',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−2516−05740',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Asuncion',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−04:00'},
#  {'Country code': 'CA',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+484531−0913718',
#   'Notes': '',
#   'Portion of country covered': 'EST - ON (Atikokan); NU (Coral H)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Atikokan',
#   'UTC DST offset ±hh:mm': '−05:00',
#   'UTC offset ±hh:mm': '−05:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to America/Adak',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'America/Atka',
#   'UTC DST offset ±hh:mm': '−09:00',
#   'UTC offset ±hh:mm': '−10:00'},
#  {'Country code': 'BR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−1259−03831',
#   'Notes': '',
#   'Portion of country covered': 'Bahia',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Bahia',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−03:00'},
#  {'Country code': 'MX',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+2048−10515',
#   'Notes': '',
#   'Portion of country covered': 'Central Time - Bahía de Banderas',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Bahia_Banderas',
#   'UTC DST offset ±hh:mm': '−05:00',
#   'UTC offset ±hh:mm': '−06:00'},
#  {'Country code': 'BB',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1306−05937',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Barbados',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−04:00'},
#  {'Country code': 'BR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−0127−04829',
#   'Notes': '',
#   'Portion of country covered': 'Pará (east); Amapá',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Belem',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−03:00'},
#  {'Country code': 'BZ',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1730−08812',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Belize',
#   'UTC DST offset ±hh:mm': '−06:00',
#   'UTC offset ±hh:mm': '−06:00'},
#  {'Country code': 'CA',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+5125−05707',
#   'Notes': '',
#   'Portion of country covered': 'AST - QC (Lower North Shore)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Blanc-Sablon',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−04:00'},
#  {'Country code': 'BR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0249−06040',
#   'Notes': '',
#   'Portion of country covered': 'Roraima',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Boa_Vista',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−04:00'},
#  {'Country code': 'CO',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0436−07405',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Bogota',
#   'UTC DST offset ±hh:mm': '−05:00',
#   'UTC offset ±hh:mm': '−05:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+433649−1161209',
#   'Notes': '',
#   'Portion of country covered': 'Mountain - ID (south); OR (east)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Boise',
#   'UTC DST offset ±hh:mm': '−06:00',
#   'UTC offset ±hh:mm': '−07:00'},
#  {'Country code': 'AR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−3436−05827',
#   'Notes': 'Link to America/Argentina/Buenos_Aires',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'America/Buenos_Aires',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−03:00'},
#  {'Country code': 'CA',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+690650−1050310',
#   'Notes': '',
#   'Portion of country covered': 'Mountain - NU (west)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Cambridge_Bay',
#   'UTC DST offset ±hh:mm': '−06:00',
#   'UTC offset ±hh:mm': '−07:00'},
#  {'Country code': 'BR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−2027−05437',
#   'Notes': '',
#   'Portion of country covered': 'Mato Grosso do Sul',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Campo_Grande',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−04:00'},
#  {'Country code': 'MX',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+2105−08646',
#   'Notes': '',
#   'Portion of country covered': 'Eastern Standard Time - Quintana Roo',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Cancun',
#   'UTC DST offset ±hh:mm': '−05:00',
#   'UTC offset ±hh:mm': '−05:00'},
#  {'Country code': 'VE',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1030−06656',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Caracas',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−04:00'},
#  {'Country code': 'AR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−2828−06547',
#   'Notes': 'Link to America/Argentina/Catamarca',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'America/Catamarca',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−03:00'},
#  {'Country code': 'GF',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0456−05220',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Cayenne',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−03:00'},
#  {'Country code': 'KY',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1918−08123',
#   'Notes': 'Link to America/Panama',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'America/Cayman',
#   'UTC DST offset ±hh:mm': '−05:00',
#   'UTC offset ±hh:mm': '−05:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+415100−0873900',
#   'Notes': '',
#   'Portion of country covered': 'Central (most areas)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Chicago',
#   'UTC DST offset ±hh:mm': '−05:00',
#   'UTC offset ±hh:mm': '−06:00'},
#  {'Country code': 'MX',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+2838−10605',
#   'Notes': '',
#   'Portion of country covered': 'Mountain Time - Chihuahua (most areas)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Chihuahua',
#   'UTC DST offset ±hh:mm': '−06:00',
#   'UTC offset ±hh:mm': '−07:00'},
#  {'Country code': 'CA',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to America/Atikokan',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'America/Coral_Harbour',
#   'UTC DST offset ±hh:mm': '−05:00',
#   'UTC offset ±hh:mm': '−05:00'},
#  {'Country code': 'AR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−3124−06411',
#   'Notes': 'Link to America/Argentina/Cordoba',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'America/Cordoba',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−03:00'},
#  {'Country code': 'CR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0956−08405',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Costa_Rica',
#   'UTC DST offset ±hh:mm': '−06:00',
#   'UTC offset ±hh:mm': '−06:00'},
#  {'Country code': 'CA',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+4906−11631',
#   'Notes': '',
#   'Portion of country covered': 'MST - BC (Creston)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Creston',
#   'UTC DST offset ±hh:mm': '−07:00',
#   'UTC offset ±hh:mm': '−07:00'},
#  {'Country code': 'BR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−1535−05605',
#   'Notes': '',
#   'Portion of country covered': 'Mato Grosso',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Cuiaba',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−04:00'},
#  {'Country code': 'CW',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1211−06900',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Curacao',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−04:00'},
#  {'Country code': 'GL',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+7646−01840',
#   'Notes': '',
#   'Portion of country covered': 'National Park (east coast)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Danmarkshavn',
#   'UTC DST offset ±hh:mm': '+00:00',
#   'UTC offset ±hh:mm': '+00:00'},
#  {'Country code': 'CA',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+6404−13925',
#   'Notes': '',
#   'Portion of country covered': 'MST - Yukon (west)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Dawson',
#   'UTC DST offset ±hh:mm': '−07:00',
#   'UTC offset ±hh:mm': '−07:00'},
#  {'Country code': 'CA',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+5946−12014',
#   'Notes': '',
#   'Portion of country covered': 'MST - BC (Dawson Cr, Ft St John)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Dawson_Creek',
#   'UTC DST offset ±hh:mm': '−07:00',
#   'UTC offset ±hh:mm': '−07:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+394421−1045903',
#   'Notes': '',
#   'Portion of country covered': 'Mountain (most areas)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Denver',
#   'UTC DST offset ±hh:mm': '−06:00',
#   'UTC offset ±hh:mm': '−07:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+421953−0830245',
#   'Notes': '',
#   'Portion of country covered': 'Eastern - MI (most areas)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Detroit',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−05:00'},
#  {'Country code': 'DM',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1518−06124',
#   'Notes': 'Link to America/Port_of_Spain',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'America/Dominica',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−04:00'},
#  {'Country code': 'CA',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+5333−11328',
#   'Notes': '',
#   'Portion of country covered': 'Mountain - AB; BC (E); SK (W)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Edmonton',
#   'UTC DST offset ±hh:mm': '−06:00',
#   'UTC offset ±hh:mm': '−07:00'},
#  {'Country code': 'BR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−0640−06952',
#   'Notes': '',
#   'Portion of country covered': 'Amazonas (west)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Eirunepe',
#   'UTC DST offset ±hh:mm': '−05:00',
#   'UTC offset ±hh:mm': '−05:00'},
#  {'Country code': 'SV',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1342−08912',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'America/El_Salvador',
#   'UTC DST offset ±hh:mm': '−06:00',
#   'UTC offset ±hh:mm': '−06:00'},
#  {'Country code': 'MX',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to America/Tijuana',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'America/Ensenada',
#   'UTC DST offset ±hh:mm': '−07:00',
#   'UTC offset ±hh:mm': '−08:00'},
#  {'Country code': 'CA',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+5848−12242',
#   'Notes': '',
#   'Portion of country covered': 'MST - BC (Ft Nelson)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Fort_Nelson',
#   'UTC DST offset ±hh:mm': '−07:00',
#   'UTC offset ±hh:mm': '−07:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to America/Indiana/Indianapolis',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'America/Fort_Wayne',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−05:00'},
#  {'Country code': 'BR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−0343−03830',
#   'Notes': '',
#   'Portion of country covered': 'Brazil (northeast: MA, PI, CE, RN, PB)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Fortaleza',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−03:00'},
#  {'Country code': 'CA',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+4612−05957',
#   'Notes': '',
#   'Portion of country covered': 'Atlantic - NS (Cape Breton)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Glace_Bay',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−04:00'},
#  {'Country code': 'GL',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+6411−05144',
#   'Notes': 'Link to America/Nuuk',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'America/Godthab',
#   'UTC DST offset ±hh:mm': '−02:00',
#   'UTC offset ±hh:mm': '−03:00'},
#  {'Country code': 'CA',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+5320−06025',
#   'Notes': '',
#   'Portion of country covered': 'Atlantic - Labrador (most areas)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Goose_Bay',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−04:00'},
#  {'Country code': 'TC',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+2128−07108',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Grand_Turk',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−05:00'},
#  {'Country code': 'GD',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1203−06145',
#   'Notes': 'Link to America/Port_of_Spain',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'America/Grenada',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−04:00'},
#  {'Country code': 'GP',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1614−06132',
#   'Notes': 'Link to America/Port_of_Spain',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'America/Guadeloupe',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−04:00'},
#  {'Country code': 'GT',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1438−09031',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Guatemala',
#   'UTC DST offset ±hh:mm': '−06:00',
#   'UTC offset ±hh:mm': '−06:00'},
#  {'Country code': 'EC',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−0210−07950',
#   'Notes': '',
#   'Portion of country covered': 'Ecuador (mainland)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Guayaquil',
#   'UTC DST offset ±hh:mm': '−05:00',
#   'UTC offset ±hh:mm': '−05:00'},
#  {'Country code': 'GY',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0648−05810',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Guyana',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−04:00'},
#  {'Country code': 'CA',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+4439−06336',
#   'Notes': '',
#   'Portion of country covered': 'Atlantic - NS (most areas); PE',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Halifax',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−04:00'},
#  {'Country code': 'CU',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+2308−08222',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Havana',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−05:00'},
#  {'Country code': 'MX',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+2904−11058',
#   'Notes': '',
#   'Portion of country covered': 'Mountain Standard Time - Sonora',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Hermosillo',
#   'UTC DST offset ±hh:mm': '−07:00',
#   'UTC offset ±hh:mm': '−07:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+394606−0860929',
#   'Notes': '',
#   'Portion of country covered': 'Eastern - IN (most areas)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Indiana/Indianapolis',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−05:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+411745−0863730',
#   'Notes': '',
#   'Portion of country covered': 'Central - IN (Starke)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Indiana/Knox',
#   'UTC DST offset ±hh:mm': '−05:00',
#   'UTC offset ±hh:mm': '−06:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+382232−0862041',
#   'Notes': '',
#   'Portion of country covered': 'Eastern - IN (Crawford)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Indiana/Marengo',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−05:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+382931−0871643',
#   'Notes': '',
#   'Portion of country covered': 'Eastern - IN (Pike)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Indiana/Petersburg',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−05:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+375711−0864541',
#   'Notes': '',
#   'Portion of country covered': 'Central - IN (Perry)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Indiana/Tell_City',
#   'UTC DST offset ±hh:mm': '−05:00',
#   'UTC offset ±hh:mm': '−06:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+384452−0850402',
#   'Notes': '',
#   'Portion of country covered': 'Eastern - IN (Switzerland)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Indiana/Vevay',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−05:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+384038−0873143',
#   'Notes': '',
#   'Portion of country covered': 'Eastern - IN (Da, Du, K, Mn)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Indiana/Vincennes',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−05:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+410305−0863611',
#   'Notes': '',
#   'Portion of country covered': 'Eastern - IN (Pulaski)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Indiana/Winamac',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−05:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+394606−0860929',
#   'Notes': 'Link to America/Indiana/Indianapolis',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'America/Indianapolis',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−05:00'},
#  {'Country code': 'CA',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+682059−1334300',
#   'Notes': '',
#   'Portion of country covered': 'Mountain - NT (west)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Inuvik',
#   'UTC DST offset ±hh:mm': '−06:00',
#   'UTC offset ±hh:mm': '−07:00'},
#  {'Country code': 'CA',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+6344−06828',
#   'Notes': '',
#   'Portion of country covered': 'Eastern - NU (most east areas)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Iqaluit',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−05:00'},
#  {'Country code': 'JM',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+175805−0764736',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Jamaica',
#   'UTC DST offset ±hh:mm': '−05:00',
#   'UTC offset ±hh:mm': '−05:00'},
#  {'Country code': 'AR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−2411−06518',
#   'Notes': 'Link to America/Argentina/Jujuy',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'America/Jujuy',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−03:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+581807−1342511',
#   'Notes': '',
#   'Portion of country covered': 'Alaska - Juneau area',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Juneau',
#   'UTC DST offset ±hh:mm': '−08:00',
#   'UTC offset ±hh:mm': '−09:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+381515−0854534',
#   'Notes': '',
#   'Portion of country covered': 'Eastern - KY (Louisville area)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Kentucky/Louisville',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−05:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+364947−0845057',
#   'Notes': '',
#   'Portion of country covered': 'Eastern - KY (Wayne)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Kentucky/Monticello',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−05:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+411745−0863730',
#   'Notes': 'Link to America/Indiana/Knox',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'America/Knox_IN',
#   'UTC DST offset ±hh:mm': '−05:00',
#   'UTC offset ±hh:mm': '−06:00'},
#  {'Country code': 'BQ',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+120903−0681636',
#   'Notes': 'Link to America/Curacao',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'America/Kralendijk',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−04:00'},
#  {'Country code': 'BO',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−1630−06809',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'America/La_Paz',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−04:00'},
#  {'Country code': 'PE',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−1203−07703',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Lima',
#   'UTC DST offset ±hh:mm': '−05:00',
#   'UTC offset ±hh:mm': '−05:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+340308−1181434',
#   'Notes': '',
#   'Portion of country covered': 'Pacific',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Los_Angeles',
#   'UTC DST offset ±hh:mm': '−07:00',
#   'UTC offset ±hh:mm': '−08:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+381515−0854534',
#   'Notes': 'Link to America/Kentucky/Louisville',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'America/Louisville',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−05:00'},
#  {'Country code': 'SX',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+180305−0630250',
#   'Notes': 'Link to America/Curacao',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'America/Lower_Princes',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−04:00'},
#  {'Country code': 'BR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−0940−03543',
#   'Notes': '',
#   'Portion of country covered': 'Alagoas, Sergipe',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Maceio',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−03:00'},
#  {'Country code': 'NI',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1209−08617',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Managua',
#   'UTC DST offset ±hh:mm': '−06:00',
#   'UTC offset ±hh:mm': '−06:00'},
#  {'Country code': 'BR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−0308−06001',
#   'Notes': '',
#   'Portion of country covered': 'Amazonas (east)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Manaus',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−04:00'},
#  {'Country code': 'MF',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1804−06305',
#   'Notes': 'Link to America/Port_of_Spain',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'America/Marigot',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−04:00'},
#  {'Country code': 'MQ',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1436−06105',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Martinique',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−04:00'},
#  {'Country code': 'MX',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+2550−09730',
#   'Notes': '',
#   'Portion of country covered': 'Central Time US - Coahuila, Nuevo León, Tamaulipas (US border)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Matamoros',
#   'UTC DST offset ±hh:mm': '−05:00',
#   'UTC offset ±hh:mm': '−06:00'},
#  {'Country code': 'MX',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+2313−10625',
#   'Notes': '',
#   'Portion of country covered': 'Mountain Time - Baja California Sur, Nayarit, Sinaloa',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Mazatlan',
#   'UTC DST offset ±hh:mm': '−06:00',
#   'UTC offset ±hh:mm': '−07:00'},
#  {'Country code': 'AR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−3253−06849',
#   'Notes': 'Link to America/Argentina/Mendoza',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'America/Mendoza',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−03:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+450628−0873651',
#   'Notes': '',
#   'Portion of country covered': 'Central - MI (Wisconsin border)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Menominee',
#   'UTC DST offset ±hh:mm': '−05:00',
#   'UTC offset ±hh:mm': '−06:00'},
#  {'Country code': 'MX',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+2058−08937',
#   'Notes': '',
#   'Portion of country covered': 'Central Time - Campeche, Yucatán',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Merida',
#   'UTC DST offset ±hh:mm': '−05:00',
#   'UTC offset ±hh:mm': '−06:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+550737−1313435',
#   'Notes': '',
#   'Portion of country covered': 'Alaska - Annette Island',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Metlakatla',
#   'UTC DST offset ±hh:mm': '−08:00',
#   'UTC offset ±hh:mm': '−09:00'},
#  {'Country code': 'MX',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1924−09909',
#   'Notes': '',
#   'Portion of country covered': 'Central Time',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Mexico_City',
#   'UTC DST offset ±hh:mm': '−05:00',
#   'UTC offset ±hh:mm': '−06:00'},
#  {'Country code': 'PM',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+4703−05620',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Miquelon',
#   'UTC DST offset ±hh:mm': '−02:00',
#   'UTC offset ±hh:mm': '−03:00'},
#  {'Country code': 'CA',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+4606−06447',
#   'Notes': '',
#   'Portion of country covered': 'Atlantic - New Brunswick',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Moncton',
#   'UTC DST offset ±hh:mm': '−03:00',
#   'UTC offset ±hh:mm': '−04:00'},
#  {'Country code': 'MX',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+2540−10019',
#   'Notes': '',
#   'Portion of country covered': 'Central Time - Durango; Coahuila, Nuevo León, Tamaulipas (most areas)',
#   'Status': 'Canonical',
#   'TZ database name': 'America/Monterrey',
#   'UTC DST offset ±hh:mm': '−05:00',
#   'UTC offset ±hh:mm': '−06:00'},
#  {'Country code': 'UY',
# ...
#   'Notes': '',
#   'Portion of country covered': 'Gambier Islands',
#   'Status': 'Canonical',
#   'TZ database name': 'Pacific/Gambier',
#   'UTC DST offset ±hh:mm': '−09:00',
#   'UTC offset ±hh:mm': '−09:00'},
#  {'Country code': 'SB',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−0932+16012',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'Pacific/Guadalcanal',
#   'UTC DST offset ±hh:mm': '+11:00',
#   'UTC offset ±hh:mm': '+11:00'},
#  {'Country code': 'GU',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1328+14445',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'Pacific/Guam',
#   'UTC DST offset ±hh:mm': '+10:00',
#   'UTC offset ±hh:mm': '+10:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+211825−1575130',
#   'Notes': '',
#   'Portion of country covered': 'Hawaii',
#   'Status': 'Canonical',
#   'TZ database name': 'Pacific/Honolulu',
#   'UTC DST offset ±hh:mm': '−10:00',
#   'UTC offset ±hh:mm': '−10:00'},
#  {'Country code': 'UM',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to Pacific/Honolulu',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'Pacific/Johnston',
#   'UTC DST offset ±hh:mm': '−10:00',
#   'UTC offset ±hh:mm': '−10:00'},
#  {'Country code': 'KI',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0152−15720',
#   'Notes': '',
#   'Portion of country covered': 'Line Islands',
#   'Status': 'Canonical',
#   'TZ database name': 'Pacific/Kiritimati',
#   'UTC DST offset ±hh:mm': '+14:00',
#   'UTC offset ±hh:mm': '+14:00'},
#  {'Country code': 'FM',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0519+16259',
#   'Notes': '',
#   'Portion of country covered': 'Kosrae',
#   'Status': 'Canonical',
#   'TZ database name': 'Pacific/Kosrae',
#   'UTC DST offset ±hh:mm': '+11:00',
#   'UTC offset ±hh:mm': '+11:00'},
#  {'Country code': 'MH',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0905+16720',
#   'Notes': '',
#   'Portion of country covered': 'Kwajalein',
#   'Status': 'Canonical',
#   'TZ database name': 'Pacific/Kwajalein',
#   'UTC DST offset ±hh:mm': '+12:00',
#   'UTC offset ±hh:mm': '+12:00'},
#  {'Country code': 'MH',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0709+17112',
#   'Notes': '',
#   'Portion of country covered': 'Marshall Islands (most areas)',
#   'Status': 'Canonical',
#   'TZ database name': 'Pacific/Majuro',
#   'UTC DST offset ±hh:mm': '+12:00',
#   'UTC offset ±hh:mm': '+12:00'},
#  {'Country code': 'PF',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−0900−13930',
#   'Notes': '',
#   'Portion of country covered': 'Marquesas Islands',
#   'Status': 'Canonical',
#   'TZ database name': 'Pacific/Marquesas',
#   'UTC DST offset ±hh:mm': '−09:30',
#   'UTC offset ±hh:mm': '−09:30'},
#  {'Country code': 'UM',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+2813−17722',
#   'Notes': 'Link to Pacific/Pago_Pago',
#   'Portion of country covered': 'Midway Islands',
#   'Status': 'Alias',
#   'TZ database name': 'Pacific/Midway',
#   'UTC DST offset ±hh:mm': '−11:00',
#   'UTC offset ±hh:mm': '−11:00'},
#  {'Country code': 'NR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−0031+16655',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'Pacific/Nauru',
#   'UTC DST offset ±hh:mm': '+12:00',
#   'UTC offset ±hh:mm': '+12:00'},
#  {'Country code': 'NU',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−1901−16955',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'Pacific/Niue',
#   'UTC DST offset ±hh:mm': '−11:00',
#   'UTC offset ±hh:mm': '−11:00'},
#  {'Country code': 'NF',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−2903+16758',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'Pacific/Norfolk',
#   'UTC DST offset ±hh:mm': '+12:00',
#   'UTC offset ±hh:mm': '+11:00'},
#  {'Country code': 'NC',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−2216+16627',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'Pacific/Noumea',
#   'UTC DST offset ±hh:mm': '+11:00',
#   'UTC offset ±hh:mm': '+11:00'},
#  {'Country code': 'AS',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−1416−17042',
#   'Notes': '',
#   'Portion of country covered': 'Samoa, Midway',
#   'Status': 'Canonical',
#   'TZ database name': 'Pacific/Pago_Pago',
#   'UTC DST offset ±hh:mm': '−11:00',
#   'UTC offset ±hh:mm': '−11:00'},
#  {'Country code': 'PW',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0720+13429',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'Pacific/Palau',
#   'UTC DST offset ±hh:mm': '+09:00',
#   'UTC offset ±hh:mm': '+09:00'},
#  {'Country code': 'PN',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−2504−13005',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'Pacific/Pitcairn',
#   'UTC DST offset ±hh:mm': '−08:00',
#   'UTC offset ±hh:mm': '−08:00'},
#  {'Country code': 'FM',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0658+15813',
#   'Notes': '',
#   'Portion of country covered': 'Pohnpei/Ponape',
#   'Status': 'Canonical',
#   'TZ database name': 'Pacific/Pohnpei',
#   'UTC DST offset ±hh:mm': '+11:00',
#   'UTC offset ±hh:mm': '+11:00'},
#  {'Country code': 'FM',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to Pacific/Pohnpei',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'Pacific/Ponape',
#   'UTC DST offset ±hh:mm': '+11:00',
#   'UTC offset ±hh:mm': '+11:00'},
#  {'Country code': 'PG',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−0930+14710',
#   'Notes': '',
#   'Portion of country covered': 'Papua New Guinea (most areas)',
#   'Status': 'Canonical',
#   'TZ database name': 'Pacific/Port_Moresby',
#   'UTC DST offset ±hh:mm': '+10:00',
#   'UTC offset ±hh:mm': '+10:00'},
#  {'Country code': 'CK',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−2114−15946',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'Pacific/Rarotonga',
#   'UTC DST offset ±hh:mm': '−10:00',
#   'UTC offset ±hh:mm': '−10:00'},
#  {'Country code': 'MP',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1512+14545',
#   'Notes': 'Link to Pacific/Guam',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'Pacific/Saipan',
#   'UTC DST offset ±hh:mm': '+10:00',
#   'UTC offset ±hh:mm': '+10:00'},
#  {'Country code': 'WS',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to Pacific/Pago_Pago',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'Pacific/Samoa',
#   'UTC DST offset ±hh:mm': '−11:00',
#   'UTC offset ±hh:mm': '−11:00'},
#  {'Country code': 'PF',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−1732−14934',
#   'Notes': '',
#   'Portion of country covered': 'Society Islands',
#   'Status': 'Canonical',
#   'TZ database name': 'Pacific/Tahiti',
#   'UTC DST offset ±hh:mm': '−10:00',
#   'UTC offset ±hh:mm': '−10:00'},
#  {'Country code': 'KI',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0125+17300',
#   'Notes': '',
#   'Portion of country covered': 'Gilbert Islands',
#   'Status': 'Canonical',
#   'TZ database name': 'Pacific/Tarawa',
#   'UTC DST offset ±hh:mm': '+12:00',
#   'UTC offset ±hh:mm': '+12:00'},
#  {'Country code': 'TO',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−2110−17510',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'Pacific/Tongatapu',
#   'UTC DST offset ±hh:mm': '+13:00',
#   'UTC offset ±hh:mm': '+13:00'},
#  {'Country code': 'FM',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to Pacific/Chuuk',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'Pacific/Truk',
#   'UTC DST offset ±hh:mm': '+10:00',
#   'UTC offset ±hh:mm': '+10:00'},
#  {'Country code': 'UM',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+1917+16637',
#   'Notes': '',
#   'Portion of country covered': 'Wake Island',
#   'Status': 'Canonical',
#   'TZ database name': 'Pacific/Wake',
#   'UTC DST offset ±hh:mm': '+12:00',
#   'UTC offset ±hh:mm': '+12:00'},
#  {'Country code': 'WF',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '−1318−17610',
#   'Notes': '',
#   'Portion of country covered': '',
#   'Status': 'Canonical',
#   'TZ database name': 'Pacific/Wallis',
#   'UTC DST offset ±hh:mm': '+12:00',
#   'UTC offset ±hh:mm': '+12:00'},
#  {'Country code': 'FM',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to Pacific/Chuuk',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'Pacific/Yap',
#   'UTC DST offset ±hh:mm': '+10:00',
#   'UTC offset ±hh:mm': '+10:00'},
#  {'Country code': 'PL',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to Europe/Warsaw',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'Poland',
#   'UTC DST offset ±hh:mm': '+02:00',
#   'UTC offset ±hh:mm': '+01:00'},
#  {'Country code': 'PT',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to Europe/Lisbon',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'Portugal',
#   'UTC DST offset ±hh:mm': '+01:00',
#   'UTC offset ±hh:mm': '+00:00'},
#  {'Country code': 'CN',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to Asia/Shanghai',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'PRC',
#   'UTC DST offset ±hh:mm': '+08:00',
#   'UTC offset ±hh:mm': '+08:00'},
#  {'Country code': '',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Choose a zone that observes PST with United States daylight saving time rules, such as America/Los_Angeles.',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'PST8PDT',
#   'UTC DST offset ±hh:mm': '−07:00',
#   'UTC offset ±hh:mm': '−08:00'},
#  {'Country code': 'TW',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to Asia/Taipei',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'ROC',
#   'UTC DST offset ±hh:mm': '+08:00',
#   'UTC offset ±hh:mm': '+08:00'},
#  {'Country code': 'KR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to Asia/Seoul',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'ROK',
#   'UTC DST offset ±hh:mm': '+09:00',
#   'UTC offset ±hh:mm': '+09:00'},
#  {'Country code': 'SG',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '+0117+10351',
#   'Notes': 'Link to Asia/Singapore',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'Singapore',
#   'UTC DST offset ±hh:mm': '+08:00',
#   'UTC offset ±hh:mm': '+08:00'},
#  {'Country code': 'TR',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to Europe/Istanbul',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'Turkey',
#   'UTC DST offset ±hh:mm': '+03:00',
#   'UTC offset ±hh:mm': '+03:00'},
#  {'Country code': '',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to Etc/UTC',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'UCT',
#   'UTC DST offset ±hh:mm': '+00:00',
#   'UTC offset ±hh:mm': '+00:00'},
#  {'Country code': '',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to Etc/UTC',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'Universal',
#   'UTC DST offset ±hh:mm': '+00:00',
#   'UTC offset ±hh:mm': '+00:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to America/Anchorage',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'US/Alaska',
#   'UTC DST offset ±hh:mm': '−08:00',
#   'UTC offset ±hh:mm': '−09:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to America/Adak',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'US/Aleutian',
#   'UTC DST offset ±hh:mm': '−09:00',
#   'UTC offset ±hh:mm': '−10:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to America/Phoenix',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'US/Arizona',
#   'UTC DST offset ±hh:mm': '−07:00',
#   'UTC offset ±hh:mm': '−07:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to America/Chicago',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'US/Central',
#   'UTC DST offset ±hh:mm': '−05:00',
#   'UTC offset ±hh:mm': '−06:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to America/Indiana/Indianapolis',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'US/East-Indiana',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−05:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to America/New_York',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'US/Eastern',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−05:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to Pacific/Honolulu',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'US/Hawaii',
#   'UTC DST offset ±hh:mm': '−10:00',
#   'UTC offset ±hh:mm': '−10:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to America/Indiana/Knox',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'US/Indiana-Starke',
#   'UTC DST offset ±hh:mm': '−05:00',
#   'UTC offset ±hh:mm': '−06:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to America/Detroit',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'US/Michigan',
#   'UTC DST offset ±hh:mm': '−04:00',
#   'UTC offset ±hh:mm': '−05:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to America/Denver',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'US/Mountain',
#   'UTC DST offset ±hh:mm': '−06:00',
#   'UTC offset ±hh:mm': '−07:00'},
#  {'Country code': 'US',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to America/Los_Angeles',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'US/Pacific',
#   'UTC DST offset ±hh:mm': '−07:00',
#   'UTC offset ±hh:mm': '−08:00'},
#  {'Country code': 'WS',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to Pacific/Pago_Pago',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'US/Samoa',
#   'UTC DST offset ±hh:mm': '−11:00',
#   'UTC offset ±hh:mm': '−11:00'},
#  {'Country code': '',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to Etc/UTC',
#   'Portion of country covered': '',
#   'Status': 'Alias',
#   'TZ database name': 'UTC',
#   'UTC DST offset ±hh:mm': '+00:00',
#   'UTC offset ±hh:mm': '+00:00'},
#  {'Country code': 'RU',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to Europe/Moscow',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'W-SU',
#   'UTC DST offset ±hh:mm': '+03:00',
#   'UTC offset ±hh:mm': '+03:00'},
#  {'Country code': '',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Choose a zone that observes WET, such as Europe/Lisbon.',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'WET',
#   'UTC DST offset ±hh:mm': '+01:00',
#   'UTC offset ±hh:mm': '+00:00'},
#  {'Country code': '',
#   'Latitude, longitude ±DDMM(SS)±DDDMM(SS)': '',
#   'Notes': 'Link to Etc/UTC',
#   'Portion of country covered': '',
#   'Status': 'Deprecated',
#   'TZ database name': 'Zulu',
#   'UTC DST offset ±hh:mm': '+00:00',
#   'UTC offset ±hh:mm': '+00:00'}]

# %%
dataframe = pandas.DataFrame(data)

dataframe.head()
# Out:
#   Country code Latitude, longitude ±DDMM(SS)±DDDMM(SS)  \
# 0           CI                             +0519−00402
# 1           GH                             +0533−00013
# 2           ET                             +0902+03842
# 3           DZ                             +3647+00303
# 4           ER                             +1520+03853
#
#                     Notes Portion of country covered     Status  \
# 0                                                     Canonical
# 1                                                     Canonical
# 2  Link to Africa/Nairobi                                 Alias
# 3                                                     Canonical
# 4  Link to Africa/Nairobi                                 Alias
#
#      TZ database name UTC DST offset ±hh:mm UTC offset ±hh:mm
# 0      Africa/Abidjan                +00:00            +00:00
# 1        Africa/Accra                +00:00            +00:00
# 2  Africa/Addis_Ababa                +03:00            +03:00
# 3      Africa/Algiers                +01:00            +01:00
# 4       Africa/Asmara                +03:00            +03:00

# %%
dataframe = dataframe.loc[dataframe.Status == "Canonical"]

dataframe.head()
# Out:
#    Country code Latitude, longitude ±DDMM(SS)±DDDMM(SS) Notes  \
# 0            CI                             +0519−00402
# 1            GH                             +0533−00013
# 3            DZ                             +3647+00303
# 9            GW                             +1151−01535
# 13           EG                             +3003+03115
#
#    Portion of country covered     Status TZ database name  \
# 0                              Canonical   Africa/Abidjan
# 1                              Canonical     Africa/Accra
# 3                              Canonical   Africa/Algiers
# 9                              Canonical    Africa/Bissau
# 13                             Canonical     Africa/Cairo
#
#    UTC DST offset ±hh:mm UTC offset ±hh:mm
# 0                 +00:00            +00:00
# 1                 +00:00            +00:00
# 3                 +01:00            +01:00
# 9                 +00:00            +00:00
# 13                +02:00            +02:00

# %%
def fixOffsetSigns(offset):
    fixedOffset = offset

    if "−" in offset:
        fixedOffset = offset.replace("−", "-")
    
    return fixedOffset

dataframe["UTC DST offset ±hh:mm"] = dataframe["UTC DST offset ±hh:mm"].apply(fixOffsetSigns)
dataframe["UTC offset ±hh:mm"] = dataframe["UTC offset ±hh:mm"].apply(fixOffsetSigns)

dataframe.head()
# Out:
#    Country code Latitude, longitude ±DDMM(SS)±DDDMM(SS) Notes  \
# 0            CI                             +0519−00402
# 1            GH                             +0533−00013
# 3            DZ                             +3647+00303
# 9            GW                             +1151−01535
# 13           EG                             +3003+03115
#
#    Portion of country covered     Status TZ database name  \
# 0                              Canonical   Africa/Abidjan
# 1                              Canonical     Africa/Accra
# 3                              Canonical   Africa/Algiers
# 9                              Canonical    Africa/Bissau
# 13                             Canonical     Africa/Cairo
#
#    UTC DST offset ±hh:mm UTC offset ±hh:mm
# 0                 +00:00            +00:00
# 1                 +00:00            +00:00
# 3                 +01:00            +01:00
# 9                 +00:00            +00:00
# 13                +02:00            +02:00

# %%
dataframe = dataframe.loc[:,["TZ database name", "UTC offset ±hh:mm", "UTC DST offset ±hh:mm"]]

dataframe.head()
# Out:
#    TZ database name UTC offset ±hh:mm UTC DST offset ±hh:mm
# 0    Africa/Abidjan            +00:00                +00:00
# 1      Africa/Accra            +00:00                +00:00
# 3    Africa/Algiers            +01:00                +01:00
# 9     Africa/Bissau            +00:00                +00:00
# 13     Africa/Cairo            +02:00                +02:00

# %%
headers = {
    "TZ database name": "zone",
    "UTC offset ±hh:mm": "offset",
    "UTC DST offset ±hh:mm": "offsetDST"
}

dataframe = dataframe.rename(columns=headers)

dataframe.head()
# Out:
#               zone  offset offsetDST
# 0   Africa/Abidjan  +00:00    +00:00
# 1     Africa/Accra  +00:00    +00:00
# 3   Africa/Algiers  +01:00    +01:00
# 9    Africa/Bissau  +00:00    +00:00
# 13    Africa/Cairo  +02:00    +02:00

# %%
dataframe.to_csv("C:\\temp\\timezone.csv", index=False, encoding="utf-8")
